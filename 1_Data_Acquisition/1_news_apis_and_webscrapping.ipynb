# %% [markdown]
# # Webscrapping and API Pulls

# %% [markdown]
# In this notebook we will collect data from a variety of sources.  We will use the NOAA API to pull in weather alerts, News API to pull in news articles based on keywords related to road closures, and we will scrape road closure alerts from the ND and MN 511 sites.
#
# Finally, we will apply spacy named entity recognition to these data sets (with the exception of ND 511).  We will not apply spacy to the ND 511 alerts here, because this set is going to be used as a training set for our model.  The other data sources are being used to locate weather alerts in Minnessota.

# %% [markdown]
# ## Table of Contents:
# * [Import Packages](#first-bullet)
# * [Weather API](#second-bullet)
# * [News API](#third-bullet)
# * [ND 511](#fourth-bullet)
# * [MN 511](#fifth-bullet)
# * [Spacy Named Entities](#sixth-bullet)

# %% [markdown]
# # Import Packages <a class="anchor" id="first-bullet"></a>

# %%
import json
import requests
import pandas as pd

# %%
import requests
from bs4 import BeautifulSoup

# %%
import en_core_web_sm
nlp = en_core_web_sm.load()
#https://github.com/explosion/spaCy/issues/1283

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
from pprint import pprint

# %% [markdown]
# # Weather API  <a class="anchor" id="second-bullet"></a>

# %% [markdown]
# Pull in data from this page - https://alerts.weather.gov/cap/us.php?x=1
# 'Watches, Warnings or Advisories for
# the United States
# This page shows alerts currently in effect for the United States and is normally updated every two-three minutes. '
#
# https://www.weather.gov/documentation/services-web-api

# %%
api_token = 'ga_nyc_students'
api_url_base = 'https://api.weather.gov/alerts/active?message_type=alert'

url = "https://api.weather.gov"


response = requests.get(url)
json   = response.json()
json
# Out:
# {'status': 'OK'}

# %%
response = requests.get(api_url_base)

# %%
print(response.status_code)
# Out:
# 200

# %%
print(response.content)
# Out:
# b'{\n    "@context": [\n        "https://raw.githubusercontent.com/geojson/geojson-ld/master/contexts/geojson-base.jsonld",\n        {\n            "wx": "https://api.weather.gov/ontology#",\n            "@vocab": "https://api.weather.gov/ontology#"\n        }\n    ],\n    "type": "FeatureCollection",\n    "features": [\n        {\n            "id": "https://api.weather.gov/alerts/NWS-IDP-PROD-KEEPALIVE-37966",\n            "type": "Feature",\n            "geometry": null,\n            "properties": {\n                "@id": "https://api.weather.gov/alerts/NWS-IDP-PROD-KEEPALIVE-37966",\n                "@type": "wx:Alert",\n                "id": "NWS-IDP-PROD-KEEPALIVE-37966",\n                "areaDesc": "Montgomery",\n                "geocode": {\n                    "UGC": [\n                        "MDC031"\n                    ],\n                    "SAME": [\n                        "024031"\n                    ]\n                },\n                "affectedZones": [\n                    "https://api.weather.gov/zones/county/MDC031"\n                ],\n                "references": [],\n                "sent": "2019-04-21T02:16:25+00:00",\n                "effective": "2019-04-21T02:16:25+00:00",\n                "onset": null,\n                "expires": "2019-04-21T02:26:25+00:00",\n                "ends": null,\n                "status": "Test",\n                "messageType": "Alert",\n                "category": "Met",\n                "severity": "Unknown",\n                "certainty": "Unknown",\n                "urgency": "Unknown",\n                "event": "Test Message",\n                "sender": "w-nws.webmaster@noaa.gov",\n                "senderName": "NWS",\n                "headline": null,\n                "description": "Monitoring message only. Please disregard.",\n                "instruction": "Monitoring message only. Please disregard.",\n                "response": "None",\n                "parameters": {\n                    "PIL": [\n                        "NWSKEPWBC"\n                    ],\n                    "BLOCKCHANNEL": [\n                        "CMAS",\n                        "EAS",\n                        "NWEM"\n                    ]\n                }\n            }\n        },\n        {\n            "id": "https://api.weather.gov/alerts/NWS-IDP-PROD-3499596",\n            "type": "Feature",\n            "geometry": {\n                "type": "Polygon",\n                "coordinates": [\n                    [\n                        [\n                            -105.84,\n                            43.740000000000002\n                        ],\n                        [\n                            -105.9599999,\n                            43.760000000000005\n                        ],\n                        [\n                            -105.94,\n                            43.960000000000008\n                        ],\n                        [\n                            -105.64,\n                            43.960000000000008\n                        ],\n                        [\n                            -105.84,\n                            43.740000000000002\n                        ]\n                    ]\n                ]\n            },\n            "properties": {\n                "@id": "https://api.weather.gov/alerts/NWS-IDP-PROD-3499596",\n                "@type": "wx:Alert",\n                "id": "NWS-IDP-PROD-3499596",\n                "areaDesc": "Southern Campbell",\n                "geocode": {\n                    "UGC": [\n                        "WYZ055"\n                    ],\n                    "SAME": [\n                        "056005"\n                    ]\n                },\n                "affectedZones": [\n                    "https://api.weather.gov/zones/forecast/WYZ055"\n                ],\n                "references": [],\n                "sent": "2019-04-20T19:58:00-06:00",\n                "effective": "2019-04-20T ...

# %%
json_obj = response.json()

# %%
json_obj
# Out:
# {'@context': ['https://raw.githubusercontent.com/geojson/geojson-ld/master/contexts/geojson-base.jsonld',
#   {'wx': 'https://api.weather.gov/ontology#',
#    '@vocab': 'https://api.weather.gov/ontology#'}],
#  'type': 'FeatureCollection',
#  'features': [{'id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-KEEPALIVE-37966',
#    'type': 'Feature',
#    'geometry': None,
#    'properties': {'@id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-KEEPALIVE-37966',
#     '@type': 'wx:Alert',
#     'id': 'NWS-IDP-PROD-KEEPALIVE-37966',
#     'areaDesc': 'Montgomery',
#     'geocode': {'UGC': ['MDC031'], 'SAME': ['024031']},
#     'affectedZones': ['https://api.weather.gov/zones/county/MDC031'],
#     'references': [],
#     'sent': '2019-04-21T02:16:25+00:00',
#     'effective': '2019-04-21T02:16:25+00:00',
#     'onset': None,
#     'expires': '2019-04-21T02:26:25+00:00',
#     'ends': None,
#     'status': 'Test',
#     'messageType': 'Alert',
#     'category': 'Met',
#     'severity': 'Unknown',
#     'certainty': 'Unknown',
#     'urgency': 'Unknown',
#     'event': 'Test Message',
#     'sender': 'w-nws.webmaster@noaa.gov',
#     'senderName': 'NWS',
#     'headline': None,
#     'description': 'Monitoring message only. Please disregard.',
#     'instruction': 'Monitoring message only. Please disregard.',
#     'response': 'None',
#     'parameters': {'PIL': ['NWSKEPWBC'],
#      'BLOCKCHANNEL': ['CMAS', 'EAS', 'NWEM']}}},
#   {'id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3499596',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-105.84, 43.74],
#       [-105.9599999, 43.760000000000005],
#       [-105.94, 43.96000000000001],
#       [-105.64, 43.96000000000001],
#       [-105.84, 43.74]]]},
#    'properties': {'@id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3499596',
#     '@type': 'wx:Alert',
#     'id': 'NWS-IDP-PROD-3499596',
#     'areaDesc': 'Southern Campbell',
#     'geocode': {'UGC': ['WYZ055'], 'SAME': ['056005']},
#     'affectedZones': ['https://api.weather.gov/zones/forecast/WYZ055'],
#     'references': [],
#     'sent': '2019-04-20T19:58:00-06:00',
#     'effective': '2019-04-20T19:58:00-06:00',
#     'onset': '2019-04-20T19:58:00-06:00',
#     'expires': '2019-04-20T20:30:00-06:00',
#     'ends': None,
#     'status': 'Actual',
#     'messageType': 'Alert',
#     'category': 'Met',
#     'severity': 'Moderate',
#     'certainty': 'Observed',
#     'urgency': 'Expected',
#     'event': 'Special Weather Statement',
#     'sender': 'w-nws.webmaster@noaa.gov',
#     'senderName': 'NWS Rapid City SD',
#     'headline': 'Special Weather Statement issued April 20 at 7:58PM MDT by NWS Rapid City SD',
#     'description': 'At 758 PM MDT, Doppler radar was tracking a strong thunderstorm 5\nmiles southwest of Savageton, or 19 miles west of Wright, moving\nnortheast at 25 mph.\n\nPea size hail and winds in excess of 40 mph will be possible with\nthis storm.\n\nLocations impacted include...\nSavageton.',
#     'instruction': '',
#     'response': 'Execute',
#     'parameters': {'eventMotionDescription': ['2019-04-20T19:58:00.000-06:00...storm...205DEG...21KT...43.81,-105.88'],
#      'NWSheadline': ['SIGNIFICANT WEATHER ADVISORY FOR SOUTHWESTERN CAMPBELL COUNTY UNTIL 830 PM MDT'],
#      'EAS-ORG': ['WXR'],
#      'PIL': ['UNRSPSUNR'],
#      'BLOCKCHANNEL': ['CMAS', 'EAS', 'NWEM']}}},
#   {'id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3499508-3059077',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-86.13, 38.78],
#       [-86.31, 38.72],
#       [-86.4599999, 38.769999999999996],
#       [-86.42999999999999, 38.81999999999999],
#       [-86.30999999999999, 38.779999999999994],
#       [-86.17999999999999, 38.8],
#       [-86.13, 38.78]]]},
#    'properties': {'@id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3499508-3059077',
#     '@type': 'wx:Alert',
#     'id': 'NWS-IDP-PROD-3499508-3059077',
#     'areaDesc': 'Martin, IN; Lawrence, IN',
#     'geocode': {'UGC': ['INC101', 'INC093'], 'SAME': ['018101', '018093']},
#     'affectedZones': ['https://api.weather.gov/zones/county/INC101',
#      'https://api.weather.gov/zones/county/INC093'],
#     'references': [],
#     'sent': '2019-04-20T21:43:00-04:00',
#     'effective': '2019-04-20T21:43:00-04:00',
#     'onset': '2019-04-21T10:10:00-04:00',
#     'expires': '2019-04-21T21:42:00-04:00',
#     'ends': '2019-04-29T05:00:00-04:00',
#     'status': 'Actual',
#     'messageType': 'Alert',
#     'category': 'Met',
#     'severity': 'Severe',
#     'certainty': 'Observed',
#     'urgency': 'Immediate',
#     'event': 'Flood Warning',
#     'sender': 'w-nws.webmaster@noaa.gov',
#     'senderName': 'NWS Indianapolis IN',
#     'headline': 'Flood Warning issued April 20 at 9:43PM EDT until April 29 at 5:00AM EDT by NWS Indianapolis IN',
#     'description': 'Big Blue River...Driftwood River...East Fork White River...Flatrock\nRiver...Mississinewa River...Muscatatuck River...Wabash River...\nWhite River...Wildcat Creek...Youngs Creek...\n\n.Lowland flooding has developed and will continue to develop across\nmany area rivers and streams across Indiana. Approximately 2 to 3\nplus inches of rain have fallen across portions of central Indiana\nsince Thursday morning, with locally higher amounts. Rain has ended\nacross the area with dry weather expected until Tuesday. Flooding\nalong smaller creeks and streams will end by tomorrow with the\nlarger rivers remaining in flood through the rest of the week.\nThe Flood Warning continues for\nThe East Fork White River near Rivervale.\n* from Sunday morning to Monday April 29.\n* At  8:30 PM Saturday the stage was 17.9 feet.\n* Flood stage is 20.0 feet.\n* Minor flooding is forecast.\n* Forecast...Rise above flood stage by Sunday morning and continue to\nrise to near 26.7 feet by Wednesday morning.  It will fall below\nflood stage by Sunday April 28.\n* At 28.0 feet...Extensive river flooding in progress.  Residential\nareas near the river begin to flood.  The county bridge locally\nknown as the Buddha bypass bridge becomes inaccessible.   Several\nlocal roads are flooded including Duncan Rd/Tunnelton Rd...Fort\nRitner at the underpass and post office...Old Buddha Rd...Tunnelton\nRd at the RR crossing and West Sparksville Bridge Rd.',
#     'instruction': 'Precautionary/Preparedness Actions...\n\nMotorists should never drive into flood water. Turn around and go\nanother way. Keep children away from flooded areas. Recreational and\nagricultural interests should remain alert to changing river\nconditions.\n\nFor detailed flood information go to weather.gov/ind on the web and\nclick on rivers and lakes.',
#     'response': 'Avoid',
#     'parameters': {'VTEC': ['/O.EXT.KIND.FL.W.0193.190421T1410Z-190429T0900Z/'],
#      'EAS-ORG': ['WXR'],
#      'PIL': ['INDFLSIND'],
#      'BLOCKCHANNEL': ['CMAS', 'EAS', 'NWEM'],
#      'eventEndingTime': ['2019-04-29T05:00:00-04:00']}}},
#   {'id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3499493-3059062',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-85.83, 39.05],
#       [-85.99, 38.86],
#       [-86.13, 38.769999999999996],
#       [-86.19999999999999, 38.79],
#       [-86.03999999999999, 38.93],
#       [-85.86999999999999, 39.06],
#       [-85.83, 39.05]]]},
#    'properties': {'@id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3499493-3059062',
#     '@type': 'wx:Alert',
#     'id': 'NWS-IDP-PROD-3499493-3059062',
#     'areaDesc': 'Lawrence, IN; Jackson, IN; Washington, IN',
#     'geocode': {'UGC': ['INC093', 'INC071', 'INC175'],
#      'SAME': ['018093', '018071', '018175']},
#     'affectedZones': ['https://api.weather.gov/zones/county/INC093',
#      'https://api.weather.gov/zones/county/INC071',
#      'https://api.weather.gov/zones/county/INC175'],
#     'references': [],
#     'sent': '2019-04-20T21:43:00-04:00',
#     'effective': '2019-04-20T21:43:00-04:00',
#     'onset': '2019-04-20T21:43:00-04:00',
#     'expires': '2019-04-21T21:42:00-04:00',
#     'ends': '2019-04-25T13:08:00-04:00',
#     'status': 'Actual',
#     'messageType': 'Alert',
#     'category': 'Met',
#     'severity': 'Severe',
#     'certainty': 'Observed',
#     'urgency': 'Immediate',
#     'event': 'Flood Warning',
#     'sender': 'w-nws.webmaster@noaa.gov',
#     'senderName': 'NWS Indianapolis IN',
#     'headline': 'Flood Warning issued April 20 at 9:43PM EDT until April 25 at 1:08PM EDT by NWS Indianapolis IN',
#     'description': 'Big Blue River...Driftwood River...East Fork White River...Flatrock\nRiver...Mississinewa River...Muscatatuck River...Wabash River...\nWhite River...Wildcat Creek...Youngs Creek...\n\n.Lowland flooding has developed and will continue to develop across\nmany area rivers and streams across Indiana. Approximately 2 to 3\nplus inches of rain have fallen across portions of central Indiana\nsince Thursday morning, with locally higher amounts. Rain has ended\nacross the area with dry weather expected until Tuesday. Flooding\nalong smaller creeks and streams will end by tomorrow with the\nlarger rivers remaining in flood through the rest of the week.\nThe Flood Warning continues for\nThe East Fork White River at Seymour.\n* until Thursday afternoon.\n* At  8:45 PM Saturday the stage was 15.9 feet.\n* Flood stage is 12.0 feet.\n* Minor flooding is occurring and Minor flooding is forecast.\n* Forecast...It will rise to near 16.6 feet by Sunday afternoon then\nbegin falling. It will fall below flood stage late Wednesday night.\n* At 16.4 feet...State Road 258 remained open after the river\nrebounded quickly to this level in June 2010.  State Road 258 had\nbeen flooded a few days earlier after river crested at 17.9 feet.',
#     'instruction': 'Precautionary/Preparedness Actions...\n\nMotorists should never drive into flood water. Turn around and go\nanother way. Keep children away from flooded areas. Recreational and\nagricultural interests should remain alert to changing river\nconditions.\n\nFor detailed flood information go to weather.gov/ind on the web and\nclick on rivers and lakes.',
#     'response': 'Avoid',
#     'parameters': {'VTEC': ['/O.EXT.KIND.FL.W.0192.000000T0000Z-190425T1708Z/'],
#      'EAS-ORG': ['WXR'],
#      'PIL': ['INDFLSIND'],
#      'BLOCKCHANNEL': ['CMAS', 'EAS', 'NWEM'],
#      'eventEndingTime': ['2019-04-25T13:08:00-04:00']}}},
#   {'id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3499487-3059056',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-85.83, 39.34],
#       [-85.88, 39.260000000000005],
#       [-85.92, 39.21000000000001],
#       [-85.95, 39.20000000000001],
#       [-85.93, 39.27000000000001],
#       [-85.89, 39.35000000000001],
#       [-85.83, 39.34]]]},
#    'properties': {'@id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3499487-3059056',
#     '@type': 'wx:Alert',
#     'id': 'NWS-IDP-PROD-3499487-3059056',
#     'areaDesc': 'Bartholomew, IN',
#     'geocode': {'UGC': ['INC005'], 'SAME': ['018005']},
#     'affectedZones': ['https://api.weather.gov/zones/county/INC005'],
#     'references': [],
#     'sent': '2019-04-20T21:43:00-04:00',
#     'effective': '2019-04-20T21:43:00-04:00',
#     'onset': '2019-04-21T02:00:00-04:00',
#     'expires': '2019-04-21T21:42:00-04:00',
#     'ends': '2019-04-22T15:30:00-04:00',
#     'status': 'Actual',
#     'messageType': 'Alert',
#     'category': 'Met',
#     'severity': 'Severe',
#     'certainty': 'Observed',
#     'urgency': 'Immediate',
#     'event': 'Flood Warning',
#     'sender': 'w-nws.webmaster@noaa.gov',
#     'senderName': 'NWS Indianapolis IN',
#     'headline': 'Flood Warning issued April 20 at 9:43PM EDT until April 22 at 3:30PM EDT by NWS Indianapolis IN',
#     'description': 'Big Blue River...Driftwood River...East Fork White River...Flatrock\nRiver...Mississinewa River...Muscatatuck River...Wabash River...\nWhite River...Wildcat Creek...Youngs Creek...\n\n.Lowland flooding has developed and will continue to develop across\nmany area rivers and streams across Indiana. Approximately 2 to 3\nplus inches of rain have fallen across portions of central Indiana\nsince Thursday morning, with locally higher amounts. Rain has ended\nacross the area with dry weather expected until Tuesday. Flooding\nalong smaller creeks and streams will end by tomorrow with the\nlarger rivers remaining in flood through the rest of the week.\nThe Flood Warning continues for\nThe Flatrock River near Columbus.\n* from late tonight to Monday afternoon.\n* At  9:30 PM Saturday the stage was 10.0 feet.\n* Flood stage is 11.0 feet.\n* Minor flooding is forecast.\n* Forecast...Rise above flood stage by late tonight and continue to\nrise to near 11.9 feet by Sunday afternoon.  It will fall below\nflood stage by Monday morning.\n* At 12.0 feet...On April 6, 2011 after reaching 13 feet...Noblitt\nPark...CR 400N and Owens Bend Park remained flooded.',
#     'instruction': 'Precautionary/Preparedness Actions...\n\nMotorists should never drive into flood water. Turn around and go\nanother way. Keep children away from flooded areas. Recreational and\nagricultural interests should remain alert to changing river\nconditions.\n\nFor detailed flood information go to weather.gov/ind on the web and\nclick on rivers and lakes.',
#     'response': 'Avoid',
#     'parameters': {'VTEC': ['/O.CON.KIND.FL.W.0224.190421T0600Z-190422T1930Z/'],
#      'EAS-ORG': ['WXR'],
#      'PIL': ['INDFLSIND'],
#      'BLOCKCHANNEL': ['CMAS', 'EAS', 'NWEM'],
#      'eventEndingTime': ['2019-04-22T15:30:00-04:00']}}},
#   {'id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3499496-3059065',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-84.9599999, 40.26],
#       [-85.28, 40.239999999999995],
#       [-85.51, 40.379999999999995],
#       [-85.43, 40.409999899999995],
#       [-85.27000000000001, 40.3],
#       [-84.95000000000002, 40.29],
#       [-84.9599999, 40.26]]]},
#    'properties': {'@id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3499496-3059065',
#     '@type': 'wx:Alert',
#     'id': 'NWS-IDP-PROD-3499496-3059065',
#     'areaDesc': 'Randolph, IN; Delaware, IN',
#     'geocode': {'UGC': ['INC135', 'INC035'], 'SAME': ['018135', '018035']},
#     'affectedZones': ['https://api.weather.gov/zones/county/INC135',
#      'https://api.weather.gov/zones/county/INC035'],
#     'references': [],
#     'sent': '2019-04-20T21:43:00-04:00',
#     'effective': '2019-04-20T21:43:00-04:00',
#     'onset': '2019-04-20T21:43:00-04:00',
#     'expires': '2019-04-21T21:42:00-04:00',
#     'ends': None,
#     'status': 'Actual',
#     'messageType': 'Alert',
#     'category': 'Met',
#     'severity': 'Severe',
#     'certainty': 'Observed',
#     'urgency': 'Immediate',
#     'event': 'Flood Warning',
#     'sender': 'w-nws.webmaster@noaa.gov',
#     'senderName': 'NWS Indianapolis IN',
#     'headline': 'Flood Warning issued April 20 at 9:43PM EDT by NWS Indianapolis IN',
#     'description': 'Big Blue River...Driftwood River...East Fork White River...Flatrock\nRiver...Mississinewa River...Muscatatuck River...Wabash River...\nWhite River...Wildcat Creek...Youngs Creek...\n\n.Lowland flooding has developed and will continue to develop across\nmany area rivers and streams across Indiana. Approximately 2 to 3\nplus inches of rain have fallen across portions of central Indiana\nsince Thursday morning, with locally higher amounts. Rain has ended\nacross the area with dry weather expected until Tuesday. Flooding\nalong smaller creeks and streams will end by tomorrow with the\nlarger rivers remaining in flood through the rest of the week.\nThe Flood Warning continues for\nThe Mississinewa River near Ridgeville.\n* until further notice.\n* At  9:00 PM Saturday the stage was 12.9 feet.\n* Flood stage is 10.0 feet.\n* Moderate flooding is occurring and Moderate flooding is forecast.\n* Forecast...It will continue rising to near 13.1 feet by this\nevening. Additional rises may be possible thereafter.\n* At 13.0 feet...Significant flooding of Mississinewa River in\nnorthern Randolph County.  Water is likely on SR 1 just south of SR\n28.  West CR 825 N east of SR 1 and West River Road west of SR 1\nand possibly other county roads are flooded.  Little League field\nin Ridgeville is flooded.  Noticeable agricultural flooding in\nprogress.',
#     'instruction': 'Precautionary/Preparedness Actions...\n\nMotorists should never drive into flood water. Turn around and go\nanother way. Keep children away from flooded areas. Recreational and\nagricultural interests should remain alert to changing river\nconditions.\n\nFor detailed flood information go to weather.gov/ind on the web and\nclick on rivers and lakes.',
#     'response': 'Avoid',
#     'parameters': {'VTEC': ['/O.EXT.KIND.FL.W.0219.000000T0000Z-000000T0000Z/'],
#      'EAS-ORG': ['WXR'],
#      'PIL': ['INDFLSIND'],
#      'BLOCKCHANNEL': ['CMAS', 'EAS', 'NWEM']}}},
#   {'id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3499503-3059072',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-85.9599999, 40.11],
#       [-85.97, 40.08],
#       [-86.05, 39.949999999999996],
#       [-86.0699999, 39.959999999999994],
#       [-86.02, 40.059999999999995],
#       [-85.97999999999999, 40.129999999999995],
#       [-85.9599999, 40.11]]]},
#    'properties': {'@id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3499503-3059072',
#     '@type': 'wx:Alert',
#     'id': 'NWS-IDP-PROD-3499503-3059072',
#     'areaDesc': 'Hamilton, IN; Marion, IN',
#     'geocode': {'UGC': ['INC057', 'INC097'], 'SAME': ['018057', '018097']},
#     'affectedZones': ['https://api.weather.gov/zones/county/INC057',
#      'https://api.weather.gov/zones/county/INC097'],
#     'references': [],
#     'sent': '2019-04-20T21:43:00-04:00',
#     'effective': '2019-04-20T21:43:00-04:00',
#     'onset': '2019-04-21T13:00:00-04:00',
#     'expires': '2019-04-21T21:42:00-04:00',
#     'ends': '2019-04-22T08:00:00-04:00',
#     'status': 'Actual',
#     'messageType': 'Alert',
#     'category': 'Met',
#     'severity': 'Severe',
#     'certainty': 'Observed',
#     'urgency': 'Immediate',
#     'event': 'Flood Warning',
#     'sender': 'w-nws.webmaster@noaa.gov',
#     'senderName': 'NWS Indianapolis IN',
#     'headline': 'Flood Warning issued April 20 at 9:43PM EDT until April 22 at 8:00AM EDT by NWS Indianapolis IN',
#     'description': 'Big Blue River...Driftwood River...East Fork White River...Flatrock\nRiver...Mississinewa River...Muscatatuck River...Wabash River...\nWhite River...Wildcat Creek...Youngs Creek...\n\n.Lowland flooding has developed and will continue to develop across\nmany area rivers and streams across Indiana. Approximately 2 to 3\nplus inches of rain have fallen across portions of central Indiana\nsince Thursday morning, with locally higher amounts. Rain has ended\nacross the area with dry weather expected until Tuesday. Flooding\nalong smaller creeks and streams will end by tomorrow with the\nlarger rivers remaining in flood through the rest of the week.\nThe Flood Warning continues for\nThe White River at Noblesville.\n* from Sunday afternoon to Monday morning.\n* At  8:45 PM Saturday the stage was 11.5 feet.\n* Flood stage is 14.0 feet.\n* Minor flooding is forecast.\n* Forecast...Rise above flood stage by Sunday afternoon and continue\nto rise to near 14.1 feet by Sunday afternoon.  It will fall below\nflood stage by Sunday evening.\n* At 14.0 feet...Agricultural flooding is readily visible north and\nsouth of Noblesville.',
#     'instruction': 'Precautionary/Preparedness Actions...\n\nMotorists should never drive into flood water. Turn around and go\nanother way. Keep children away from flooded areas. Recreational and\nagricultural interests should remain alert to changing river\nconditions.\n\nFor detailed flood information go to weather.gov/ind on the web and\nclick on rivers and lakes.',
#     'response': 'Avoid',
#     'parameters': {'VTEC': ['/O.EXT.KIND.FL.W.0198.190421T1700Z-190422T1200Z/'],
#      'EAS-ORG': ['WXR'],
#      'PIL': ['INDFLSIND'],
#      'BLOCKCHANNEL': ['CMAS', 'EAS', 'NWEM'],
#      'eventEndingTime': ['2019-04-22T08:00:00-04:00']}}},
#   {'id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3499497-3059066',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-85.47, 39.8],
#       [-85.64, 39.669999999999995],
#       [-85.74, 39.51],
#       [-85.8, 39.54],
#       [-85.73, 39.71],
#       [-85.53, 39.82],
#       [-85.47, 39.8]]]},
#    'properties': {'@id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3499497-3059066',
#     '@type': 'wx:Alert',
#     'id': 'NWS-IDP-PROD-3499497-3059066',
#     'areaDesc': 'Rush, IN; Henry, IN; Shelby, IN',
#     'geocode': {'UGC': ['INC139', 'INC065', 'INC145'],
#      'SAME': ['018139', '018065', '018145']},
#     'affectedZones': ['https://api.weather.gov/zones/county/INC139',
#      'https://api.weather.gov/zones/county/INC065',
#      'https://api.weather.gov/zones/county/INC145'],
#     'references': [],
#     'sent': '2019-04-20T21:43:00-04:00',
#     'effective': '2019-04-20T21:43:00-04:00',
#     'onset': '2019-04-20T23:30:00-04:00',
#     'expires': '2019-04-21T07:44:00-04:00',
#     'ends': '2019-04-21T07:44:00-04:00',
#     'status': 'Actual',
#     'messageType': 'Alert',
#     'category': 'Met',
#     'severity': 'Severe',
#     'certainty': 'Observed',
#     'urgency': 'Immediate',
#     'event': 'Flood Warning',
#     'sender': 'w-nws.webmaster@noaa.gov',
#     'senderName': 'NWS Indianapolis IN',
#     'headline': 'Flood Warning issued April 20 at 9:43PM EDT until April 21 at 7:44AM EDT by NWS Indianapolis IN',
#     'description': 'Big Blue River...Driftwood River...East Fork White River...Flatrock\nRiver...Mississinewa River...Muscatatuck River...Wabash River...\nWhite River...Wildcat Creek...Youngs Creek...\n\n.Lowland flooding has developed and will continue to develop across\nmany area rivers and streams across Indiana. Approximately 2 to 3\nplus inches of rain have fallen across portions of central Indiana\nsince Thursday morning, with locally higher amounts. Rain has ended\nacross the area with dry weather expected until Tuesday. Flooding\nalong smaller creeks and streams will end by tomorrow with the\nlarger rivers remaining in flood through the rest of the week.\nThe Flood Warning continues for\nThe Big Blue River at Carthage.\n* until Sunday morning.\n* At  8:45 PM Saturday the stage was 6.7 feet.\n* Flood stage is 7.0 feet.\n* Minor flooding is forecast.\n* Forecast...Rise above flood stage by this evening and continue to\nrise to near 7.1 feet by late tonight.  It will fall below flood\nstage by late tonight.\n* At 7.0 feet...Lowland flooding begins.',
#     'instruction': 'Precautionary/Preparedness Actions...\n\nMotorists should never drive into flood water. Turn around and go\nanother way. Keep children away from flooded areas. Recreational and\nagricultural interests should remain alert to changing river\nconditions.\n\nFor detailed flood information go to weather.gov/ind on the web and\nclick on rivers and lakes.',
#     'response': 'Avoid',
#     'parameters': {'VTEC': ['/O.CON.KIND.FL.W.0223.190421T0330Z-190421T1144Z/'],
#      'EAS-ORG': ['WXR'],
#      'PIL': ['INDFLSIND'],
#      'BLOCKCHANNEL': ['CMAS', 'EAS', 'NWEM'],
#      'eventEndingTime': ['2019-04-21T07:44:00-04:00']}}},
#   {'id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3499510-3059079',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-85.95, 39.36],
#       [-85.95, 39.22],
#       [-85.92, 39.22],
#       [-85.91, 39.199999999999996],
#       [-85.97, 39.199999999999996],
#       [-86.01, 39.37],
#       [-85.95, 39.36]]]},
#    'properties': {'@id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3499510-3059079',
#     '@type': 'wx:Alert',
#     'id': 'NWS-IDP-PROD-3499510-3059079',
#     'areaDesc': 'Johnson, IN; Bartholomew, IN; Shelby, IN',
#     'geocode': {'UGC': ['INC081', 'INC005', 'INC145'],
#      'SAME': ['018081', '018005', '018145']},
#     'affectedZones': ['https://api.weather.gov/zones/county/INC081',
#      'https://api.weather.gov/zones/county/INC005',
#      'https://api.weather.gov/zones/county/INC145'],
#     'references': [],
#     'sent': '2019-04-20T21:43:00-04:00',
#     'effective': '2019-04-20T21:43:00-04:00',
#     'onset': '2019-04-21T04:00:00-04:00',
#     'expires': '2019-04-21T21:42:00-04:00',
#     'ends': '2019-04-23T15:12:00-04:00',
#     'status': 'Actual',
#     'messageType': 'Alert',
#     'category': 'Met',
#     'severity': 'Severe',
#     'certainty': 'Observed',
#     'urgency': 'Immediate',
#     'event': 'Flood Warning',
#     'sender': 'w-nws.webmaster@noaa.gov',
#     'senderName': 'NWS Indianapolis IN',
#     'headline': 'Flood Warning issued April 20 at 9:43PM EDT until April 23 at 3:12PM EDT by NWS Indianapolis IN',
#     'description': 'Big Blue River...Driftwood River...East Fork White River...Flatrock\nRiver...Mississinewa River...Muscatatuck River...Wabash River...\nWhite River...Wildcat Creek...Youngs Creek...\n\n.Lowland flooding has developed and will continue to develop across\nmany area rivers and streams across Indiana. Approximately 2 to 3\nplus inches of rain have fallen across portions of central Indiana\nsince Thursday morning, with locally higher amounts. Rain has ended\nacross the area with dry weather expected until Tuesday. Flooding\nalong smaller creeks and streams will end by tomorrow with the\nlarger rivers remaining in flood through the rest of the week.\nThe Flood Warning continues for\nThe Driftwood River near Edinburgh 2 SW.\n* from late tonight to Tuesday afternoon.\n* At  8:30 PM Saturday the stage was 10.1 feet.\n* Flood stage is 11.0 feet.\n* Minor flooding is forecast.\n* Forecast...Rise above flood stage by late tonight and continue to\nrise to near 12.9 feet by late Sunday night.  It will fall below\nflood stage by late Monday night.\n* At 13.2 feet...Lowland flooding in progress along Driftwood River in\nnorthern Bartholomew County on April 6, 2011. Double Y Saddle Club\narea flooded.  At least 6 inches of water flowing over CR 950N to\nClub. Water is less than one foot away from CR 330W just south of\nits intersection with Ohio Ridge Rd. CR 500N west of CR 250W is\nflooded blocking vehicular access to residences near the river\nbank. Lowell Public Access site is open but ramp is totally\nflooded. Water close to one residence at Shelby CR 1000S and CR\n900W.',
#     'instruction': 'Precautionary/Preparedness Actions...\n\nMotorists should never drive into flood water. Turn around and go\nanother way. Keep children away from flooded areas. Recreational and\nagricultural interests should remain alert to changing river\nconditions.\n\nFor detailed flood information go to weather.gov/ind on the web and\nclick on rivers and lakes.',
#     'response': 'Avoid',
#     'parameters': {'VTEC': ['/O.EXT.KIND.FL.W.0190.190421T0800Z-190423T1912Z/'],
#      'EAS-ORG': ['WXR'],
#      'PIL': ['INDFLSIND'],
#      'BLOCKCHANNEL': ['CMAS', 'EAS', 'NWEM'],
#      'eventEndingTime': ['2019-04-23T15:12:00-04:00']}}},
#   {'id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3499509-3059078',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-86.65, 39.34],
#       [-86.75, 39.28],
#       [-86.92, 39.11],
#       [-86.9599999, 39.13],
#       [-86.74, 39.330000000000005],
#       [-86.66, 39.36000000000001],
#       [-86.65, 39.34]]]},
#    'properties': {'@id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3499509-3059078',
#     '@type': 'wx:Alert',
#     'id': 'NWS-IDP-PROD-3499509-3059078',
#     'areaDesc': 'Monroe, IN; Greene, IN; Owen, IN',
#     'geocode': {'UGC': ['INC105', 'INC055', 'INC119'],
#      'SAME': ['018105', '018055', '018119']},
#     'affectedZones': ['https://api.weather.gov/zones/county/INC105',
#      'https://api.weather.gov/zones/county/INC055',
#      'https://api.weather.gov/zones/county/INC119'],
#     'references': [],
#     'sent': '2019-04-20T21:43:00-04:00',
#     'effective': '2019-04-20T21:43:00-04:00',
#     'onset': '2019-04-20T21:43:00-04:00',
#     'expires': '2019-04-21T21:42:00-04:00',
#     'ends': '2019-04-26T07:20:00-04:00',
#     'status': 'Actual',
#     'messageType': 'Alert',
#     'category': 'Met',
#     'severity': 'Severe',
#     'certainty': 'Observed',
#     'urgency': 'Immediate',
#     'event': 'Flood Warning',
#     'sender': 'w-nws.webmaster@noaa.gov',
#     'senderName': 'NWS Indianapolis IN',
#     'headline': 'Flood Warning issued April 20 at 9:43PM EDT until April 26 at 7:20AM EDT by NWS Indianapolis IN',
#     'description': 'Big Blue River...Driftwood River...East Fork White River...Flatrock\nRiver...Mississinewa River...Muscatatuck River...Wabash River...\nWhite River...Wildcat Creek...Youngs Creek...\n\n.Lowland flooding has developed and will continue to develop across\nmany area rivers and streams across Indiana. Approximately 2 to 3\nplus inches of rain have fallen across portions of central Indiana\nsince Thursday morning, with locally higher amounts. Rain has ended\nacross the area with dry weather expected until Tuesday. Flooding\nalong smaller creeks and streams will end by tomorrow with the\nlarger rivers remaining in flood through the rest of the week.\nThe Flood Warning continues for\nThe White River at Spencer.\n* until Friday morning.\n* At  8:30 PM Saturday the stage was 14.0 feet.\n* Flood stage is 14.0 feet.\n* Minor flooding is occurring and Minor flooding is forecast.\n* Forecast...It will rise to near 16.2 feet by late Tuesday night\nthen begin falling. It will fall below flood stage Thursday\nevening.\n* At 16.3 feet...County Line Road south of Gosport begins to flood.',
#     'instruction': 'Precautionary/Preparedness Actions...\n\nMotorists should never drive into flood water. Turn around and go\nanother way. Keep children away from flooded areas. Recreational and\nagricultural interests should remain alert to changing river\nconditions.\n\nFor detailed flood information go to weather.gov/ind on the web and\nclick on rivers and lakes.',
#     'response': 'Avoid',
#     'parameters': {'VTEC': ['/O.EXT.KIND.FL.W.0202.000000T0000Z-190426T1120Z/'],
#      'EAS-ORG': ['WXR'],
#      'PIL': ['INDFLSIND'],
#      'BLOCKCHANNEL': ['CMAS', 'EAS', 'NWEM'],
#      'eventEndingTime': ['2019-04-26T07:20:00-04:00']}}},
#   {'id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3499506-3059075',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-86.02, 39.45],
#       [-85.99, 39.43],
#       [-85.97999999999999, 39.38],
#       [-86.02, 39.370000000000005],
#       [-86.02, 39.42],
#       [-86.05, 39.45],
#       [-86.02, 39.45]]]},
#    'properties': {'@id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3499506-3059075',
#     '@type': 'wx:Alert',
#     'id': 'NWS-IDP-PROD-3499506-3059075',
#     'areaDesc': 'Johnson, IN',
#     'geocode': {'UGC': ['INC081'], 'SAME': ['018081']},
#     'affectedZones': ['https://api.weather.gov/zones/county/INC081'],
#     'references': [],
#     'sent': '2019-04-20T21:43:00-04:00',
#     'effective': '2019-04-20T21:43:00-04:00',
#     'onset': '2019-04-20T21:43:00-04:00',
#     'expires': '2019-04-21T07:18:00-04:00',
#     'ends': '2019-04-21T07:18:00-04:00',
#     'status': 'Actual',
#     'messageType': 'Alert',
#     'category': 'Met',
#     'severity': 'Severe',
#     'certainty': 'Observed',
#     'urgency': 'Immediate',
#     'event': 'Flood Warning',
#     'sender': 'w-nws.webmaster@noaa.gov',
#     'senderName': 'NWS Indianapolis IN',
#     'headline': 'Flood Warning issued April 20 at 9:43PM EDT until April 21 at 7:18AM EDT by NWS Indianapolis IN',
#     'description': 'Big Blue River...Driftwood River...East Fork White River...Flatrock\nRiver...Mississinewa River...Muscatatuck River...Wabash River...\nWhite River...Wildcat Creek...Youngs Creek...\n\n.Lowland flooding has developed and will continue to develop across\nmany area rivers and streams across Indiana. Approximately 2 to 3\nplus inches of rain have fallen across portions of central Indiana\nsince Thursday morning, with locally higher amounts. Rain has ended\nacross the area with dry weather expected until Tuesday. Flooding\nalong smaller creeks and streams will end by tomorrow with the\nlarger rivers remaining in flood through the rest of the week.\nThe Flood Warning continues for\nThe Youngs Creek at Amity.\n* until Sunday morning.\n* At  9:15 PM Saturday the stage was 7.1 feet.\n* Flood stage is 7.0 feet.\n* Minor flooding is occurring and Minor flooding is forecast.\n* Forecast...It will rise to near 7.2 feet by this evening then begin\nfalling. It will fall below flood stage late tonight.\n* At 7.0 feet...Youngs Creek at flood stage.  Most low areas along\ncreek are flooded.   Approaches to CR 400S bridge over Youngs Creek\nbegin to flood.',
#     'instruction': 'Precautionary/Preparedness Actions...\n\nMotorists should never drive into flood water. Turn around and go\nanother way. Keep children away from flooded areas. Recreational and\nagricultural interests should remain alert to changing river\nconditions.\n\nFor detailed flood information go to weather.gov/ind on the web and\nclick on rivers and lakes.',
#     'response': 'Avoid',
#     'parameters': {'VTEC': ['/O.CON.KIND.FL.W.0222.000000T0000Z-190421T1118Z/'],
#      'EAS-ORG': ['WXR'],
#      'PIL': ['INDFLSIND'],
#      'BLOCKCHANNEL': ['CMAS', 'EAS', 'NWEM'],
#      'eventEndingTime': ['2019-04-21T07:18:00-04:00']}}},
#   {'id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3499500-3059069',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-86.92, 39.12],
#       [-86.94, 39.08],
#       [-86.92999999999999, 39],
#       [-86.97, 39],
#       [-86.99, 39.05],
#       [-86.9599999, 39.129999999999995],
#       [-86.92, 39.12]]]},
#    'properties': {'@id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3499500-3059069',
#     '@type': 'wx:Alert',
#     'id': 'NWS-IDP-PROD-3499500-3059069',
#     'areaDesc': 'Daviess, IN; Knox, IN; Greene, IN',
#     'geocode': {'UGC': ['INC027', 'INC083', 'INC055'],
#      'SAME': ['018027', '018083', '018055']},
#     'affectedZones': ['https://api.weather.gov/zones/county/INC027',
#      'https://api.weather.gov/zones/county/INC083',
#      'https://api.weather.gov/zones/county/INC055'],
#     'references': [],
#     'sent': '2019-04-20T21:43:00-04:00',
#     'effective': '2019-04-20T21:43:00-04:00',
#     'onset': '2019-04-20T21:43:00-04:00',
#     'expires': '2019-04-21T21:42:00-04:00',
#     'ends': '2019-04-27T05:00:00-04:00',
#     'status': 'Actual',
#     'messageType': 'Alert',
#     'category': 'Met',
#     'severity': 'Severe',
#     'certainty': 'Observed',
#     'urgency': 'Immediate',
#     'event': 'Flood Warning',
#     'sender': 'w-nws.webmaster@noaa.gov',
#     'senderName': 'NWS Indianapolis IN',
#     'headline': 'Flood Warning issued April 20 at 9:43PM EDT until April 27 at 5:00AM EDT by NWS Indianapolis IN',
#     'description': 'Big Blue River...Driftwood River...East Fork White River...Flatrock\nRiver...Mississinewa River...Muscatatuck River...Wabash River...\nWhite River...Wildcat Creek...Youngs Creek...\n\n.Lowland flooding has developed and will continue to develop across\nmany area rivers and streams across Indiana. Approximately 2 to 3\nplus inches of rain have fallen across portions of central Indiana\nsince Thursday morning, with locally higher amounts. Rain has ended\nacross the area with dry weather expected until Tuesday. Flooding\nalong smaller creeks and streams will end by tomorrow with the\nlarger rivers remaining in flood through the rest of the week.\nThe Flood Warning continues for\nThe White River at Elliston.\n* until Saturday April 27.\n* At  7:50 AM Saturday the stage was 20.0 feet.\n* Flood stage is 18.0 feet.\n* Minor flooding is occurring and Minor flooding is forecast.\n* Forecast...It will rise to near 22.1 feet by Sunday afternoon then\nbegin falling. It will fall below flood stage Friday afternoon.\n* At 23.0 feet...Extensive flooding of agricultural lands begin.',
#     'instruction': 'Precautionary/Preparedness Actions...\n\nMotorists should never drive into flood water. Turn around and go\nanother way. Keep children away from flooded areas. Recreational and\nagricultural interests should remain alert to changing river\nconditions.\n\nFor detailed flood information go to weather.gov/ind on the web and\nclick on rivers and lakes.',
#     'response': 'Avoid',
#     'parameters': {'VTEC': ['/O.EXT.KIND.FL.W.0180.000000T0000Z-190427T0900Z/'],
#      'EAS-ORG': ['WXR'],
#      'PIL': ['INDFLSIND'],
#      'BLOCKCHANNEL': ['CMAS', 'EAS', 'NWEM'],
#      'eventEndingTime': ['2019-04-27T05:00:00-04:00']}}},
#   {'id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3499511-3059080',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-87.12, 38.85],
#       [-87.23, 38.77],
#       [-87.23, 38.550000000000004],
#       [-87.26, 38.550000000000004],
#       [-87.29, 38.790000000000006],
#       [-87.15, 38.870000000000005],
#       [-87.12, 38.85]]]},
#    'properties': {'@id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3499511-3059080',
#     '@type': 'wx:Alert',
#     'id': 'NWS-IDP-PROD-3499511-3059080',
#     'areaDesc': 'Daviess, IN; Knox, IN; Gibson, IN; Pike, IN',
#     'geocode': {'UGC': ['INC027', 'INC083', 'INC051', 'INC125'],
#      'SAME': ['018027', '018083', '018051', '018125']},
#     'affectedZones': ['https://api.weather.gov/zones/county/INC027',
#      'https://api.weather.gov/zones/county/INC083',
#      'https://api.weather.gov/zones/county/INC051',
#      'https://api.weather.gov/zones/county/INC125'],
#     'references': [],
#     'sent': '2019-04-20T21:43:00-04:00',
#     'effective': '2019-04-20T21:43:00-04:00',
#     'onset': '2019-04-20T21:43:00-04:00',
#     'expires': '2019-04-21T21:42:00-04:00',
#     'ends': '2019-04-28T08:45:00-04:00',
#     'status': 'Actual',
#     'messageType': 'Alert',
#     'category': 'Met',
#     'severity': 'Severe',
#     'certainty': 'Observed',
#     'urgency': 'Immediate',
#     'event': 'Flood Warning',
#     'sender': 'w-nws.webmaster@noaa.gov',
#     'senderName': 'NWS Indianapolis IN',
#     'headline': 'Flood Warning issued April 20 at 9:43PM EDT until April 28 at 8:45AM EDT by NWS Indianapolis IN',
#     'description': 'Big Blue River...Driftwood River...East Fork White River...Flatrock\nRiver...Mississinewa River...Muscatatuck River...Wabash River...\nWhite River...Wildcat Creek...Youngs Creek...\n\n.Lowland flooding has developed and will continue to develop across\nmany area rivers and streams across Indiana. Approximately 2 to 3\nplus inches of rain have fallen across portions of central Indiana\nsince Thursday morning, with locally higher amounts. Rain has ended\nacross the area with dry weather expected until Tuesday. Flooding\nalong smaller creeks and streams will end by tomorrow with the\nlarger rivers remaining in flood through the rest of the week.\nThe Flood Warning continues for\nThe White River at Edwardsport.\n* until Sunday April 28.\n* At  7:00 PM Saturday the stage was 18.0 feet.\n* Flood stage is 15.0 feet.\n* Minor flooding is occurring and Minor flooding is forecast.\n* Forecast...It will rise to near 19.0 feet by Monday morning then\nbegin falling. It will fall below flood stage Saturday April 27.\n* At 18.6 feet...During June 2010 and March 2011 high water...INDOT\nclosed SR 358 between SR 67 at Edwardsport to SR 57 at Plainville.\nSR 358 floods on the east side of the river between the levees.',
#     'instruction': 'Precautionary/Preparedness Actions...\n\nMotorists should never drive into flood water. Turn around and go\nanother way. Keep children away from flooded areas. Recreational and\nagricultural interests should remain alert to changing river\nconditions.\n\nFor detailed flood information go to weather.gov/ind on the web and\nclick on rivers and lakes.',
#     'response': 'Avoid',
#     'parameters': {'VTEC': ['/O.EXT.KIND.FL.W.0182.000000T0000Z-190428T1245Z/'],
#      'EAS-ORG': ['WXR'],
#      'PIL': ['INDFLSIND'],
#      'BLOCKCHANNEL': ['CMAS', 'EAS', 'NWEM'],
#      'eventEndingTime': ['2019-04-28T08:45:00-04:00']}}},
#   {'id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3499513-3059082',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-86.09, 39.9099999],
#       [-86.13000000000001, 39.870000000000005],
#       [-86.19000000000001, 39.81],
#       [-86.20999990000001, 39.82],
#       [-86.16000000000001, 39.88],
#       [-86.11000000000001, 39.9099999],
#       [-86.09, 39.9099999]]]},
#    'properties': {'@id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3499513-3059082',
#     '@type': 'wx:Alert',
#     'id': 'NWS-IDP-PROD-3499513-3059082',
#     'areaDesc': 'Morgan, IN; Marion, IN',
#     'geocode': {'UGC': ['INC109', 'INC097'], 'SAME': ['018109', '018097']},
#     'affectedZones': ['https://api.weather.gov/zones/county/INC109',
#      'https://api.weather.gov/zones/county/INC097'],
#     'references': [],
#     'sent': '2019-04-20T21:43:00-04:00',
#     'effective': '2019-04-20T21:43:00-04:00',
#     'onset': '2019-04-21T10:00:00-04:00',
#     'expires': '2019-04-21T21:42:00-04:00',
#     'ends': '2019-04-23T06:30:00-04:00',
#     'status': 'Actual',
#     'messageType': 'Alert',
#     'category': 'Met',
#     'severity': 'Severe',
#     'certainty': 'Observed',
#     'urgency': 'Immediate',
#     'event': 'Flood Warning',
#     'sender': 'w-nws.webmaster@noaa.gov',
#     'senderName': 'NWS Indianapolis IN',
#     'headline': 'Flood Warning issued April 20 at 9:43PM EDT until April 23 at 6:30AM EDT by NWS Indianapolis IN',
#     'description': 'Big Blue River...Driftwood River...East Fork White River...Flatrock\nRiver...Mississinewa River...Muscatatuck River...Wabash River...\nWhite River...Wildcat Creek...Youngs Creek...\n\n.Lowland flooding has developed and will continue to develop across\nmany area rivers and streams across Indiana. Approximately 2 to 3\nplus inches of rain have fallen across portions of central Indiana\nsince Thursday morning, with locally higher amounts. Rain has ended\nacross the area with dry weather expected until Tuesday. Flooding\nalong smaller creeks and streams will end by tomorrow with the\nlarger rivers remaining in flood through the rest of the week.\nThe Flood Warning continues for\nThe White River at Ravenswood.\n* from Sunday morning to Tuesday morning.\n* There have been no observations in the last 24 hours.\n* Flood stage is 6.0 feet.\n* Minor flooding is forecast.\n* Forecast...It is forecast to rise above flood stage Sunday morning,\ncrest at 6.6 feet late Sunday night, and then fall below flood\nstage by Monday evening.\n* At 7.0 feet...Water surrounds homes in River Edge Estates.  A few\nstreets flood in Ravenswood.',
#     'instruction': 'Precautionary/Preparedness Actions...\n\nMotorists should never drive into flood water. Turn around and go\nanother way. Keep children away from flooded areas. Recreational and\nagricultural interests should remain alert to changing river\nconditions.\n\nFor detailed flood information go to weather.gov/ind on the web and\nclick on rivers and lakes.',
#     'response': 'Avoid',
#     'parameters': {'VTEC': ['/O.EXT.KIND.FL.W.0199.190421T1400Z-190423T1030Z/'],
#      'EAS-ORG': ['WXR'],
#      'PIL': ['INDFLSIND'],
#      'BLOCKCHANNEL': ['CMAS', 'EAS', 'NWEM'],
#      'eventEndingTime': ['2019-04-23T06:30:00-04:00']}}},
#   {'id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3499488-3059057',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-86.45, 38.77],
#       [-86.51, 38.790000000000006],
#       [-86.5699999, 38.82000000000001],
#       [-86.56, 38.85000000000001],
#       [-86.5, 38.830000000000005],
#       [-86.43, 38.81],
#       [-86.45, 38.77]]]},
#    'properties': {'@id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3499488-3059057',
#     '@type': 'wx:Alert',
#     'id': 'NWS-IDP-PROD-3499488-3059057',
#     'areaDesc': 'Martin, IN; Lawrence, IN',
#     'geocode': {'UGC': ['INC101', 'INC093'], 'SAME': ['018101', '018093']},
#     'affectedZones': ['https://api.weather.gov/zones/county/INC101',
#      'https://api.weather.gov/zones/county/INC093'],
#     'references': [],
#     'sent': '2019-04-20T21:43:00-04:00',
#     'effective': '2019-04-20T21:43:00-04:00',
#     'onset': '2019-04-22T10:15:00-04:00',
#     'expires': '2019-04-21T21:42:00-04:00',
#     'ends': '2019-04-28T20:00:00-04:00',
#     'status': 'Actual',
#     'messageType': 'Alert',
#     'category': 'Met',
#     'severity': 'Severe',
#     'certainty': 'Observed',
#     'urgency': 'Immediate',
#     'event': 'Flood Warning',
#     'sender': 'w-nws.webmaster@noaa.gov',
#     'senderName': 'NWS Indianapolis IN',
#     'headline': 'Flood Warning issued April 20 at 9:43PM EDT until April 28 at 8:00PM EDT by NWS Indianapolis IN',
#     'description': 'Big Blue River...Driftwood River...East Fork White River...Flatrock\nRiver...Mississinewa River...Muscatatuck River...Wabash River...\nWhite River...Wildcat Creek...Youngs Creek...\n\n.Lowland flooding has developed and will continue to develop across\nmany area rivers and streams across Indiana. Approximately 2 to 3\nplus inches of rain have fallen across portions of central Indiana\nsince Thursday morning, with locally higher amounts. Rain has ended\nacross the area with dry weather expected until Tuesday. Flooding\nalong smaller creeks and streams will end by tomorrow with the\nlarger rivers remaining in flood through the rest of the week.\nThe Flood Warning continues for\nThe East Fork White River near Bedford.\n* from Monday morning to Sunday April 28.\n* There have been no observations in the last 24 hours.\n* Flood stage is 20.0 feet.\n* Minor flooding is forecast.\n* Forecast...It is forecast to rise above flood stage Monday morning,\ncrest at 23.9 feet Wednesday afternoon, and then fall below flood\nstage by Sunday April 28.\n* At 24.0 feet...Limited parking at Bedford Boat Club.  Flood waters\ncover much of the parking lot and is too deep for a normal person\nto drive in.',
#     'instruction': 'Precautionary/Preparedness Actions...\n\nMotorists should never drive into flood water. Turn around and go\nanother way. Keep children away from flooded areas. Recreational and\nagricultural interests should remain alert to changing river\nconditions.\n\nFor detailed flood information go to weather.gov/ind on the web and\nclick on rivers and lakes.',
#     'response': 'Avoid',
#     'parameters': {'VTEC': ['/O.EXT.KIND.FL.W.0217.190422T1415Z-190429T0000Z/'],
#      'EAS-ORG': ['WXR'],
#      'PIL': ['INDFLSIND'],
#      'BLOCKCHANNEL': ['CMAS', 'EAS', 'NWEM'],
#      'eventEndingTime': ['2019-04-28T20:00:00-04:00']}}},
#   {'id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3499489-3059058',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-85.64, 40.09],
#       [-85.8199999, 40.13],
#       [-85.9599999, 40.11],
#       [-85.98, 40.13],
#       [-85.85000000000001, 40.150000000000006],
#       [-85.65, 40.120000000000005],
#       [-85.64, 40.09]]]},
#    'properties': {'@id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3499489-3059058',
#     '@type': 'wx:Alert',
#     'id': 'NWS-IDP-PROD-3499489-3059058',
#     'areaDesc': 'Madison, IN; Hamilton, IN',
#     'geocode': {'UGC': ['INC095', 'INC057'], 'SAME': ['018095', '018057']},
#     'affectedZones': ['https://api.weather.gov/zones/county/INC095',
#      'https://api.weather.gov/zones/county/INC057'],
#     'references': [],
#     'sent': '2019-04-20T21:43:00-04:00',
#     'effective': '2019-04-20T21:43:00-04:00',
#     'onset': '2019-04-20T22:53:00-04:00',
#     'expires': '2019-04-21T21:42:00-04:00',
#     'ends': '2019-04-22T21:00:00-04:00',
#     'status': 'Actual',
#     'messageType': 'Alert',
#     'category': 'Met',
#     'severity': 'Severe',
#     'certainty': 'Observed',
#     'urgency': 'Immediate',
#     'event': 'Flood Warning',
#     'sender': 'w-nws.webmaster@noaa.gov',
#     'senderName': 'NWS Indianapolis IN',
#     'headline': 'Flood Warning issued April 20 at 9:43PM EDT until April 22 at 9:00PM EDT by NWS Indianapolis IN',
# ...
#     'references': [],
#     'sent': '2019-04-20T05:15:00-07:00',
#     'effective': '2019-04-20T05:15:00-07:00',
#     'onset': '2019-04-20T05:15:00-07:00',
#     'expires': '2019-04-21T11:00:00-07:00',
#     'ends': '2019-04-21T11:00:00-07:00',
#     'status': 'Actual',
#     'messageType': 'Alert',
#     'category': 'Met',
#     'severity': 'Severe',
#     'certainty': 'Likely',
#     'urgency': 'Expected',
#     'event': 'Flood Warning',
#     'sender': 'w-nws.webmaster@noaa.gov',
#     'senderName': 'NWS Missoula MT',
#     'headline': 'Flood Warning issued April 20 at 5:15AM PDT until April 21 at 11:00AM PDT by NWS Missoula MT',
#     'description': 'The National Weather Service in Missoula has issued a\n\n* Flood Warning for...\nSouth Fork Clearwater River at Stites in...\nCentral Idaho County in central Idaho...\n\n* Until further notice.\n\n* The river is expected to reach the flood stage of 8 feet this\nmorning.\n\n* At 8 feet expect possible flooding to State Highway 13 near the\ntown of Harpster.',
#     'instruction': "Do not enter or cross flowing water or water of unknown depth.\n\nTurn around, don't drown when encountering flooded roads. Most flood\ndeaths occur in vehicles.",
#     'response': 'Avoid',
#     'parameters': {'VTEC': ['/O.NEW.KMSO.FA.W.0002.190420T1215Z-190421T1800Z/'],
#      'EAS-ORG': ['WXR'],
#      'PIL': ['MSOFLWMSO'],
#      'BLOCKCHANNEL': ['CMAS', 'EAS', 'NWEM'],
#      'eventEndingTime': ['2019-04-21T11:00:00-07:00']}}},
#   {'id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3498144-3057992',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-86.14, 45.99],
#       [-86.18, 45.97],
#       [-86.26, 45.949999999999996],
#       [-86.29, 45.94],
#       [-86.26, 46.03],
#       [-86.16000000000001, 46.07],
#       [-86.14, 45.99]]]},
#    'properties': {'@id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3498144-3057992',
#     '@type': 'wx:Alert',
#     'id': 'NWS-IDP-PROD-3498144-3057992',
#     'areaDesc': 'Schoolcraft, MI',
#     'geocode': {'UGC': ['MIC153'], 'SAME': ['026153']},
#     'affectedZones': ['https://api.weather.gov/zones/county/MIC153'],
#     'references': [],
#     'sent': '2019-04-20T07:52:00-04:00',
#     'effective': '2019-04-20T07:52:00-04:00',
#     'onset': '2019-04-20T07:51:00-04:00',
#     'expires': '2019-04-21T19:51:00-04:00',
#     'ends': None,
#     'status': 'Actual',
#     'messageType': 'Alert',
#     'category': 'Met',
#     'severity': 'Minor',
#     'certainty': 'Observed',
#     'urgency': 'Expected',
#     'event': 'Flood Advisory',
#     'sender': 'w-nws.webmaster@noaa.gov',
#     'senderName': 'NWS Marquette MI',
#     'headline': 'Flood Advisory issued April 20 at 7:51AM EDT by NWS Marquette MI',
#     'description': 'Manistique River near Manistique affecting Schoolcraft County\n\n.Warmer temperatures throughout the weekend combined with recent\nrainfall will continue to enable runoff from the melting snowpack.\nSnowpack remains across the northern areas of the Manistique\nRiver Basin. The river is expected to remain above bankfull\nthroughout the weekend into early next week. Moderate to heavy\nrain is possible Monday into early Tuesday.\nThe National Weather Service in Marquette has issued a\n* Flood Advisory for\nThe Manistique River near Manistique.\n* until further notice.\n* At 6 AM Saturday the stage was 11.1 feet.\n* Bankfull stage is 11.0 feet.\n* At 10.5 feet...Considerable overflow of riverbanks and flooding of\nlow lying wooded areas in the vicinity of the gauge is occurring.',
#     'instruction': 'PRECAUTIONARY/PREPAREDNESS ACTIONS...\n\nSafety message...Residents along these rivers should remain alert and\nexercise caution when walking near riverbanks.\n\nA Flood Advisory means minor flooding is possible and rivers are\nforecast to exceed bankfull. If you are in the advisory area remain\nalert to possible flooding...or the possibility of the advisory being\nupgraded to a warning. Report observed flooding to local emergency\nservices or law enforcement and request they pass this information on\nto the National Weather Service.\n\nStay tuned to NOAA Weather Radio or your favorite media outlet for\nfurther developments and information from the National Weather\nService.',
#     'response': 'Avoid',
#     'parameters': {'VTEC': ['/O.NEW.KMQT.FL.Y.0011.190420T1151Z-000000T0000Z/'],
#      'PIL': ['MQTFLSMQT'],
#      'BLOCKCHANNEL': ['CMAS', 'EAS', 'NWEM']}}},
#   {'id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3498138-3057978',
#    'type': 'Feature',
#    'geometry': None,
#    'properties': {'@id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3498138-3057978',
#     '@type': 'wx:Alert',
#     'id': 'NWS-IDP-PROD-3498138-3057978',
#     'areaDesc': 'Orofino/Grangeville Region',
#     'geocode': {'UGC': ['IDZ007'], 'SAME': ['016049', '016035']},
#     'affectedZones': ['https://api.weather.gov/zones/forecast/IDZ007'],
#     'references': [],
#     'sent': '2019-04-20T05:34:00-06:00',
#     'effective': '2019-04-20T05:34:00-06:00',
#     'onset': '2019-04-20T05:34:00-06:00',
#     'expires': '2019-04-21T06:00:00-06:00',
#     'ends': '2019-04-21T06:00:00-06:00',
#     'status': 'Actual',
#     'messageType': 'Alert',
#     'category': 'Met',
#     'severity': 'Severe',
#     'certainty': 'Possible',
#     'urgency': 'Future',
#     'event': 'Flood Watch',
#     'sender': 'w-nws.webmaster@noaa.gov',
#     'senderName': 'NWS Missoula MT',
#     'headline': 'Flood Watch issued April 20 at 5:34AM MDT until April 21 at 6:00AM MDT by NWS Missoula MT',
#     'description': 'The National Weather Service in Missoula has issued a\n\n* Flood Watch for the South Fork Clearwater River at Stites.\n\n* Through late tonight.\n\n* Primary area of concern: South Fork Clearwater River at Stites,\nwhich could reach minor flood stage this morning. Minor stream\nand creek flooding is also possible throughout the remainder of\nthe area.\n\n* Basis for the watch: Periods of moderate to heavy rain will\ncombine with snow melt to produce considerable runoff across\nnorth- central Idaho. Streams and creeks may reach near\nbankfull with mainstream rivers rising considerably, thus minor\nflooding is possible.',
#     'instruction': 'A Flood Watch means there is a potential for flooding based on\ncurrent forecasts.\n\nYou should monitor later forecasts and be alert for possible\nFlood Warnings. Those living in areas prone to flooding should be\nprepared to take action should flooding develop.',
#     'response': 'Prepare',
#     'parameters': {'NWSheadline': ['FLOOD WATCH IN EFFECT THROUGH LATE TONIGHT'],
#      'VTEC': ['/O.NEW.KMSO.FA.A.0003.190420T1134Z-190421T1200Z/'],
#      'EAS-ORG': ['WXR'],
#      'PIL': ['MSOFFAMSO'],
#      'BLOCKCHANNEL': ['CMAS', 'EAS', 'NWEM'],
#      'eventEndingTime': ['2019-04-21T06:00:00-06:00']}}},
#   {'id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3495148-3055473',
#    'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-82.62, 35.5],
#       [-82.61, 35.6],
#       [-82.65, 35.690000000000005],
#       [-82.5699999, 35.7],
#       [-82.55, 35.580000000000005],
#       [-82.53999999999999, 35.50000000000001],
#       [-82.62, 35.5]]]},
#    'properties': {'@id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3495148-3055473',
#     '@type': 'wx:Alert',
#     'id': 'NWS-IDP-PROD-3495148-3055473',
#     'areaDesc': 'Buncombe, NC',
#     'geocode': {'UGC': ['NCC021'], 'SAME': ['037021']},
#     'affectedZones': ['https://api.weather.gov/zones/county/NCC021'],
#     'references': [],
#     'sent': '2019-04-19T11:54:00-04:00',
#     'effective': '2019-04-19T11:54:00-04:00',
#     'onset': '2019-04-19T11:54:00-04:00',
#     'expires': '2019-04-20T11:53:00-04:00',
#     'ends': '2019-04-20T23:53:00-04:00',
#     'status': 'Actual',
#     'messageType': 'Alert',
#     'category': 'Met',
#     'severity': 'Minor',
#     'certainty': 'Observed',
#     'urgency': 'Expected',
#     'event': 'Flood Advisory',
#     'sender': 'w-nws.webmaster@noaa.gov',
#     'senderName': 'NWS Greenville-Spartanburg SC',
#     'headline': 'Flood Advisory issued April 19 at 11:54AM EDT until April 20 at 11:53PM EDT by NWS Greenville-Spartanburg SC',
#     'description': 'French Broad River At Asheville affecting Buncombe County\n\nHeavy rain moving across the area has saturated the ground and caused\nriver levels to rise. Additional rainfall will likely cause the river\nto crest just below flood stage.\nThe National Weather Service in Greenville-Spartanburg has issued a\n* Flood Advisory for\nThe French Broad River At Asheville.\n* until Saturday evening.\n* At 11 AM Friday the stage was 5.7 feet.\n* Action Stage is 6.5 feet.\n* Minor Flood Stage is 9.5 feet.\n* FORECAST: The river will rise to near 9.3 feet by Saturday morning.\n* IMPACTS: At 10.5 feet: Minor Flooding continues.  French Broad River\nfloodwaters may be approaching industrial buildings on the right\nbank between Woodfin and Pearson Bridge Rd.  Floodwaters may also\nbe approaching industrial buildings between Haywood Rd. and Amboy\nRd..\n* IMPACTS: At 9.5 feet: Minor Flood Stage.  The French Broad River is\nflooding areas between Riverside Dr., and Lyman St. on the right\nbank and Riverview Dr., Craven St. and Emma Rd. on the left bank,\nincluding railroad and industrial property.  Parts of Emma Rd.\nbetween Pearson Bridge Rd. and Craven St. may be flooding..\n* IMPACTS: At 8.0 feet: Action stage flooding continues.  The French\nBroad River is beginning to flood low-lying areas near Pearson\nBridge Rd. and may be approaching industrial property..\n* IMPACTS: At 7.5 feet: Action stage flooding continues.  French Broad\nRiver floodwaters continue to flood Woodfin Riverside Park, the\nfloodplain adjacent to Craggy Dam Reservoir, Carrier Park, and\nFrench Broad River Park as well as other low-lying areas within the\nflood plain.  Floodwaters may be approaching Amboy Rd. and Lyman\nSt.  Local small tributaries including Smith Mill Creek near Emma\nRd. may be exceeding bankfull levels..\n* IMPACTS: At 6.5 feet: Action Stage.  The French Broad River is\nexceeding its banks and beginning to flood low-lying areas,\nincluding the Woodfin Riverside Park, the floodplain adjacent to\nCraggy Dam Reservoir, Carrier Park, and French Broad River Park..',
#     'instruction': 'PRECAUTIONARY/PREPAREDNESS ACTIONS...\n\nA Flood Advisory for a river forecast point means that nuisance\nflooding is expected to occur along the river when the river level is\nforecast to be just below or at the official  flood stage.\n\nCaution is urged when walking near river banks...keep children away\nfrom drainage areas and culverts.',
#     'response': 'Avoid',
#     'parameters': {'VTEC': ['/O.NEW.KGSP.FL.Y.0024.190419T1554Z-190421T0353Z/'],
#      'PIL': ['GSPFLSGSP'],
#      'BLOCKCHANNEL': ['CMAS', 'EAS', 'NWEM'],
#      'eventEndingTime': ['2019-04-20T23:53:00-04:00']}}},
#   {'id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3491276-3052300',
#    'type': 'Feature',
#    'geometry': None,
#    'properties': {'@id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3491276-3052300',
#     '@type': 'wx:Alert',
#     'id': 'NWS-IDP-PROD-3491276-3052300',
#     'areaDesc': 'Windsor; Northern Franklin; Eastern Essex; Western Franklin; Western Clinton; Eastern Franklin; Eastern Rutland; Lamoille; Caledonia; Southwestern St. Lawrence; Western Addison; Western Rutland; Essex; Eastern Chittenden; Grand Isle; Eastern Clinton; Western Essex; Southern Franklin; Northern St. Lawrence; Orleans; Washington; Orange; Eastern Addison; Southeastern St. Lawrence; Western Chittenden',
#     'geocode': {'UGC': ['VTZ012',
#       'NYZ027',
#       'NYZ035',
#       'VTZ002',
#       'NYZ031',
#       'VTZ016',
#       'VTZ019',
#       'VTZ006',
#       'VTZ007',
#       'NYZ087',
#       'VTZ009',
#       'VTZ011',
#       'VTZ004',
#       'VTZ017',
#       'VTZ001',
#       'NYZ028',
#       'NYZ034',
#       'NYZ030',
#       'NYZ026',
#       'VTZ003',
#       'VTZ008',
#       'VTZ010',
#       'VTZ018',
#       'NYZ029',
#       'VTZ005'],
#      'SAME': ['050027',
#       '036033',
#       '036031',
#       '050011',
#       '036019',
#       '050021',
#       '050015',
#       '050005',
#       '036089',
#       '050001',
#       '050009',
#       '050007',
#       '050013',
#       '050019',
#       '050023',
#       '050017']},
#     'affectedZones': ['https://api.weather.gov/zones/forecast/VTZ012',
#      'https://api.weather.gov/zones/forecast/NYZ027',
#      'https://api.weather.gov/zones/forecast/NYZ035',
#      'https://api.weather.gov/zones/forecast/VTZ002',
#      'https://api.weather.gov/zones/forecast/NYZ031',
#      'https://api.weather.gov/zones/forecast/VTZ016',
#      'https://api.weather.gov/zones/forecast/VTZ019',
#      'https://api.weather.gov/zones/forecast/VTZ006',
#      'https://api.weather.gov/zones/forecast/VTZ007',
#      'https://api.weather.gov/zones/forecast/NYZ087',
#      'https://api.weather.gov/zones/forecast/VTZ009',
#      'https://api.weather.gov/zones/forecast/VTZ011',
#      'https://api.weather.gov/zones/forecast/VTZ004',
#      'https://api.weather.gov/zones/forecast/VTZ017',
#      'https://api.weather.gov/zones/forecast/VTZ001',
#      'https://api.weather.gov/zones/forecast/NYZ028',
#      'https://api.weather.gov/zones/forecast/NYZ034',
#      'https://api.weather.gov/zones/forecast/NYZ030',
#      'https://api.weather.gov/zones/forecast/NYZ026',
#      'https://api.weather.gov/zones/forecast/VTZ003',
#      'https://api.weather.gov/zones/forecast/VTZ008',
#      'https://api.weather.gov/zones/forecast/VTZ010',
#      'https://api.weather.gov/zones/forecast/VTZ018',
#      'https://api.weather.gov/zones/forecast/NYZ029',
#      'https://api.weather.gov/zones/forecast/VTZ005'],
#     'references': [],
#     'sent': '2019-04-18T03:55:00-04:00',
#     'effective': '2019-04-18T03:55:00-04:00',
#     'onset': '2019-04-19T18:00:00-04:00',
#     'expires': '2019-04-18T17:00:00-04:00',
#     'ends': '2019-04-21T12:00:00-04:00',
#     'status': 'Actual',
#     'messageType': 'Alert',
#     'category': 'Met',
#     'severity': 'Severe',
#     'certainty': 'Possible',
#     'urgency': 'Future',
#     'event': 'Flood Watch',
#     'sender': 'w-nws.webmaster@noaa.gov',
#     'senderName': 'NWS Burlington VT',
#     'headline': 'Flood Watch issued April 18 at 3:55AM EDT until April 21 at 12:00PM EDT by NWS Burlington VT',
#     'description': 'The National Weather Service in Burlington has issued a\n\n* Flood Watch for all of northern New York, and all of central and\nnorthern Vermont.\n\n* From Friday evening through Sunday morning.\n\n* Moderate to locally heavy rainfall Friday into Saturday along\nwith snowmelt in higher elevations will lead to sharp rises on\nmany local rivers and streams. Main stem rivers most at risk for\nflooding include the Passumpsic, the Wells, the Missisquoi, the\nLamoille, the Winooski, the Ausable, and the Saranac Rivers.\nSharp river rises will begin Friday. Most main stem rivers are\nexpected to crest during the day Saturday into the first part of\nSaturday night. Additionally, Lake Champlain may approach of\nexceed minor flood stage by this weekend or early next week.\n\n* Those with interests in low-lying or flood prone areas should\ncontinue to monitor the latest forecasts.',
#     'instruction': 'A Flood Watch means there is a potential for flooding based on\ncurrent forecasts.\n\nYou should monitor later forecasts and be alert for possible\nFlood Warnings. Those living in areas prone to flooding should be\nprepared to take action should flooding develop.\n\nPersons with interests in flood prone areas along Lake Champlain\nshould take action to protect their property. The combination of wind\nand wave action will enhance flood effects on windward facing shores,\nand may cause additional damage to shoreline roads and low lying\nareas.',
#     'response': 'Prepare',
#     'parameters': {'NWSheadline': ['FLOOD WATCH IN EFFECT FROM FRIDAY EVENING THROUGH SUNDAY MORNING'],
#      'VTEC': ['/O.NEW.KBTV.FA.A.0003.190419T2200Z-190421T1600Z/'],
#      'EAS-ORG': ['WXR'],
#      'PIL': ['BTVFFABTV'],
#      'BLOCKCHANNEL': ['CMAS', 'EAS', 'NWEM'],
#      'eventEndingTime': ['2019-04-21T12:00:00-04:00']}}}],
#  'title': 'current watches, warnings, and advisories',
#  'updated': '2019-04-21T02:16:38+00:00'}

# %%
print(response.headers)
# Out:
# {'Server': 'nginx/1.12.2', 'Content-Type': 'application/geo+json', 'Last-Modified': 'Sun, 21 Apr 2019 02:16:38 GMT', 'Access-Control-Allow-Origin': '*', 'X-Server-ID': 'vm-lnx-nids-apiapp9.ncep.noaa.gov', 'X-Correlation-ID': '56a8c68b-77d4-45f8-812d-7be5b45ae40c', 'X-Request-ID': '56a8c68b-77d4-45f8-812d-7be5b45ae40c', 'Content-Encoding': 'gzip', 'Content-Length': '25750', 'Cache-Control': 'public, max-age=30, s-maxage=30', 'Expires': 'Sun, 21 Apr 2019 02:26:05 GMT', 'Date': 'Sun, 21 Apr 2019 02:25:35 GMT', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding, Accept,Feature-Flags', 'Strict-Transport-Security': 'max-age=31536000 ; includeSubDomains ; preload'}

# %%
weather_df = pd.DataFrame(json_obj['features'])

# %%
weather_df.head()
# Out:
#                                             geometry  \
# 0                                               None
# 1  {'type': 'Polygon', 'coordinates': [[[-105.84,...
# 2  {'type': 'Polygon', 'coordinates': [[[-86.13, ...
# 3  {'type': 'Polygon', 'coordinates': [[[-85.83, ...
# 4  {'type': 'Polygon', 'coordinates': [[[-85.83, ...
#
#                                                   id  \
# 0  https://api.weather.gov/alerts/NWS-IDP-PROD-KE...
# 1  https://api.weather.gov/alerts/NWS-IDP-PROD-34...
# 2  https://api.weather.gov/alerts/NWS-IDP-PROD-34...
# 3  https://api.weather.gov/alerts/NWS-IDP-PROD-34...
# 4  https://api.weather.gov/alerts/NWS-IDP-PROD-34...
#
#                                           properties     type
# 0  {'@id': 'https://api.weather.gov/alerts/NWS-ID...  Feature
# 1  {'@id': 'https://api.weather.gov/alerts/NWS-ID...  Feature
# 2  {'@id': 'https://api.weather.gov/alerts/NWS-ID...  Feature
# 3  {'@id': 'https://api.weather.gov/alerts/NWS-ID...  Feature
# 4  {'@id': 'https://api.weather.gov/alerts/NWS-ID...  Feature

# %%
weather_df = pd.DataFrame(columns = ['area', 'expires', 'headline', 'description'])

for i in json_obj['features']:
    area = i['properties']['areaDesc']
    expires = i['properties']['expires']
    headline = i['properties']['headline']
    description = i['properties']['description']
    weather_df = weather_df.append({'area': area,'expires': expires,'headline': headline,'description': description}, ignore_index=True)

# %%
weather_df.head()
# Out:
#                                         area                    expires  \
# 0                                 Montgomery  2019-04-21T02:26:25+00:00
# 1                          Southern Campbell  2019-04-20T20:30:00-06:00
# 2                   Martin, IN; Lawrence, IN  2019-04-21T21:42:00-04:00
# 3  Lawrence, IN; Jackson, IN; Washington, IN  2019-04-21T21:42:00-04:00
# 4                            Bartholomew, IN  2019-04-21T21:42:00-04:00
#
#                                             headline  \
# 0                                               None
# 1  Special Weather Statement issued April 20 at 7...
# 2  Flood Warning issued April 20 at 9:43PM EDT un...
# 3  Flood Warning issued April 20 at 9:43PM EDT un...
# 4  Flood Warning issued April 20 at 9:43PM EDT un...
#
#                                          description
# 0         Monitoring message only. Please disregard.
# 1  At 758 PM MDT, Doppler radar was tracking a st...
# 2  Big Blue River...Driftwood River...East Fork W...
# 3  Big Blue River...Driftwood River...East Fork W...
# 4  Big Blue River...Driftwood River...East Fork W...

# %%
len(weather_df)
# Out:
# 60

# %% [markdown]
# Below are some of the alerts that may be relevant to our interests.  There are multiple alerts alerting users to road closures.  More specifically to our current interests (road closures in Minnesota), there is an alert regarding flooding in the state.

# %%
print(weather_df['description'][weather_df['description'].str.contains("road closure")])
# Out:
# Name: description, dtype: object

# %%
print(weather_df['description'][weather_df['area'].str.contains("MN")])
# Out:
# 36    Minnesota River At Ortonville\nThe National Weather Service in Aberdeen has issued a\n\n* Flood Warning for\nThe Minnesota River At Ortonville.\n* until further notice.\n* At  3:30 PM Saturday the stage was 10.0 feet.\n* Flood stage is 10.0 feet.
# Name: description, dtype: object

# %% [markdown]
# # News API  <a class="anchor" id="third-bullet"></a>

# %% [markdown]
# The News API has both a free and paid version.  We are working with the free version, which only allows users to pull in one page per search term.  The paid version allows users to pull in multiple pages per search term.  The function defined below works with both version of the API.  If a user is using the free version, they should always set num_pages to 1.  If they are using the paid version, they may set it higher.  If a free user attempts to set the num_pages higher than 1, the API will return an error code:
#
# "You have requested too many results. Developer accounts are limited to a max of 100 results. You are trying to request results 300 to 400.Please upgrade to a paid plan if you need more results."
#
# The function will not break however, but only one page of results per search term will be returned.

# %%
news_api_key = 'a4125c9be11c4b9d8edc5e827379c2fd'

# %%
def pull_news(phrase, num_pages):
    df_news_all = pd.DataFrame(columns = ['author', 'content', 'description', 'publishedAt', 'source', 'title', 'url', 'urlToImage'])    
    all_pulls = []
    for i in range(1, num_pages):
        url = ('https://newsapi.org/v2/everything?q='+ phrase + 
               '&apiKey=' + news_api_key + '&pageSize=100&page=' + str(i) + '&language=en')
        print(url)
        response = requests.get(url)
        print(response)
        if response.status_code == 200:
            json_obj_news = response.json()
            df_news = pd.DataFrame(json_obj_news['articles'])
            print(len(df_news))
            df_news_all = pd.concat([df_news_all.reset_index(drop=True), df_news.reset_index(drop=True)], axis=0)
            print(len(df_news_all))
        else:
            pass
    return df_news_all

# %% [markdown]
# We are interested in a variety of search terms.  We will loop through the function above to pull in multiple search terms.

# %%
# loop through multiple news topics and combine in one df

news_topics = ['road', 'road closure', 'closure', 'highway' , 'flood', 'snow', 'storm', 
               'flood', 'floods', 'flooding', 'storms', 'minnesota', 'landslide', 'blizzard', 'ice']
df_news_all_topics = pd.DataFrame(columns = ['author', 'content', 'description', 'publishedAt', 'source', 'title', 'url', 'urlToImage'])    

for i in news_topics:
    print(i)
    news_all_df = pull_news(i, 2)
    df_news_all_topics = pd.concat([df_news_all_topics.reset_index(drop=True), news_all_df.reset_index(drop=True)], axis=0)
# Out:
# road
# https://newsapi.org/v2/everything?q=road&apiKey=a4125c9be11c4b9d8edc5e827379c2fd&pageSize=100&page=1&language=en
# <Response [200]>
# 100
# 100
# road closure
# https://newsapi.org/v2/everything?q=road closure&apiKey=a4125c9be11c4b9d8edc5e827379c2fd&pageSize=100&page=1&language=en
# <Response [200]>
# 100
# 100
# closure
# https://newsapi.org/v2/everything?q=closure&apiKey=a4125c9be11c4b9d8edc5e827379c2fd&pageSize=100&page=1&language=en
# <Response [200]>
# 100
# 100
# highway
# https://newsapi.org/v2/everything?q=highway&apiKey=a4125c9be11c4b9d8edc5e827379c2fd&pageSize=100&page=1&language=en
# <Response [200]>
# 100
# 100
# flood
# https://newsapi.org/v2/everything?q=flood&apiKey=a4125c9be11c4b9d8edc5e827379c2fd&pageSize=100&page=1&language=en
# <Response [200]>
# 100
# 100
# snow
# https://newsapi.org/v2/everything?q=snow&apiKey=a4125c9be11c4b9d8edc5e827379c2fd&pageSize=100&page=1&language=en
# <Response [200]>
# 100
# 100
# storm
# https://newsapi.org/v2/everything?q=storm&apiKey=a4125c9be11c4b9d8edc5e827379c2fd&pageSize=100&page=1&language=en
# <Response [200]>
# 100
# 100
# flood
# https://newsapi.org/v2/everything?q=flood&apiKey=a4125c9be11c4b9d8edc5e827379c2fd&pageSize=100&page=1&language=en
# <Response [200]>
# 100
# 100
# floods
# https://newsapi.org/v2/everything?q=floods&apiKey=a4125c9be11c4b9d8edc5e827379c2fd&pageSize=100&page=1&language=en
# <Response [200]>
# 100
# 100
# flooding
# https://newsapi.org/v2/everything?q=flooding&apiKey=a4125c9be11c4b9d8edc5e827379c2fd&pageSize=100&page=1&language=en
# <Response [200]>
# 100
# 100
# storms
# https://newsapi.org/v2/everything?q=storms&apiKey=a4125c9be11c4b9d8edc5e827379c2fd&pageSize=100&page=1&language=en
# <Response [200]>
# 100
# 100
# minnesota
# https://newsapi.org/v2/everything?q=minnesota&apiKey=a4125c9be11c4b9d8edc5e827379c2fd&pageSize=100&page=1&language=en
# <Response [200]>
# 100
# 100
# landslide
# https://newsapi.org/v2/everything?q=landslide&apiKey=a4125c9be11c4b9d8edc5e827379c2fd&pageSize=100&page=1&language=en
# <Response [200]>
# 100
# 100
# blizzard
# https://newsapi.org/v2/everything?q=blizzard&apiKey=a4125c9be11c4b9d8edc5e827379c2fd&pageSize=100&page=1&language=en
# <Response [200]>
# 100
# 100
# ice
# https://newsapi.org/v2/everything?q=ice&apiKey=a4125c9be11c4b9d8edc5e827379c2fd&pageSize=100&page=1&language=en
# <Response [200]>
# 100
# 100

# %%
len(df_news_all_topics)
# Out:
# 1500

# %%
# https://newsapi.org/docs/endpoints/everything

# %% [markdown]
# # North Dakota DOT 511 Web scrapping  <a class="anchor" id="fourth-bullet"></a>

# %% [markdown]
# In this section, we will scrape the ND 511 site for road closure alerts.  This site has a large numbner of alerts (as of April 2018).  Because this site is geographically close to MN and contains more alerts than MN 511, it will be used to train our model to recognize likely road closure alerts.

# %%
url = 'https://www.dot.nd.gov/dotnet/news/Public/Index'

res = requests.get(url)

# %%
res.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(res.content, 'lxml')

# %%
soup.find()
# Out:
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="NDDOT" name="author"/>
# <meta content="NDDOT Internet Forms" name="North Dakota Department of Transportation Internet Forms"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>NDDOT - News Releases</title>
# <link href="https://cdn.datatables.net/1.10.15/css/dataTables.bootstrap.min.css" rel="stylesheet"/>
# <link href="/assets/css/lightslider.css" rel="stylesheet" type="text/css"/>
# <!-- Bootstrap core CSS -->
# <link href="/assets/css/bootstrap.css" media="all" rel="stylesheet"/>
# <!-- Custom styles for this template -->
# <link href="/assets/css/app.css" media="handheld, screen" rel="stylesheet"/>
# <link href="/assets/css/xs-device.css?ver=1.2" media="handheld, screen" rel="stylesheet"/>
# <link href="/assets/css/sm-device.css?ver=1.1" media="handheld, screen" rel="stylesheet"/>
# <link href="/assets/css/md-device.css" media="handheld, screen" rel="stylesheet"/>
# <link href="/assets/css/lg-device.css" media="handheld, screen" rel="stylesheet"/>
# <link href="https://www.nd.gov/banner/css/mobile-banner.css" media="handheld, screen" rel="stylesheet"/>
# <link href="/assets/css/fixed-navigation.css" media="handheld, screen" rel="stylesheet"/>
# <link href="/dotnet/news/Content/ViewSpecific/publicsearch.css" rel="stylesheet"/>
# <script src="/dotnet/news/Scripts/jquery-1.12.4.js"></script>
# <script src="/dotnet/news/Scripts/jquery-ui-1.12.0.js"></script>
# <script src="/dotnet/news/Scripts/bootstrap.js"></script>
# <script src="/dotnet/news/Scripts/respond.js"></script>
# <script src="/dotnet/news/Scripts/modernizr-2.6.2.js"></script>
# <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->
# <!--[if lt IE 9]>
# 		  <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
# 		  <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
# 	<![endif]-->
# </head>
# <body>
# <div class="bodyShrink max-width-1201">
# <nav class="hidden-print navbar-fixed-top navbar-fixed-top-special-logo">
# <div id="ndbanner">
# <div id="ndbanner-inner">
# <div id="ndbanner-ndgov"><a class="external-exception" href="http://www.nd.gov/#"><img alt="nd.gov - The Official Portal for North Dakota State Government" height="23" src="https://www.nd.gov/banner/images/ndgov-banner.jpg" width="436"/></a></div>
# <!--
# <div id="ndbanner-commerce"><a class="external-exception" href="http://www.ndtourism.com/#"><img src="https://www.nd.gov/banner/images/tourism-banner-red.gif" width="95" height="25"
# alt="North Dakota: Legendary. Follow the trail of legends" /></a></div> -->
# </div>
# </div>
# </nav>
# <!-- Start Of Body Content -->
# <div class="container" id="topOfPage">
# <!-- mobile menu that needs work. -->
# <div class="row hidden-lg hidden-md">
# <div class="col-md-12 mobile-menu">
# <nav class="navbar navbar-default navbar-fixed-top navbar-fixed-top-mobile-special"><!--navbar-static-top-->
# <div class="navbar-header">
# <button aria-controls="navbar" aria-expanded="false" class="navbar-toggle fixed collapsed pull-left" data-target=".navbar-collapsible" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle Navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <div class="social-icon-container">
# <span class="mobile-icon">
# <a href="/" title="">
# <img alt="NDDOT" class="img-responsive" src="/assets/img/nddot-logo-stacked.png" width="29"/>
# </a>
# </span>
# <span class="mobile-icon">
# <a href="https://www.facebook.com/nddot" title="">
# <img alt="DOT Facebook" class="img-responsive" src="/assets/img/facebook-mobile.png"/>
# </a>
# </span>
# <span class="mobile-icon">
# <a class="external-exception" href="https://www.linkedin.com/company/north-dakota-department-of-transportation?trk=ppro_cprof" title="LinkedIn Page">
# <img alt="NDDOT LinkedIn" class="img-responsive" src="/assets/img/linkedIn-mobile.png"/>
# </a>
# </span>
# <span class="mobile-icon">
# <a href="https://www.flickr.com/photos/nddot/" title="">
# <img alt="NDDOT Flicker" class="img-responsive" src="/assets/img/flicker-mobile.png"/>
# </a>
# </span>
# <span class="mobile-icon">
# <a href="https://www.youtube.com/user/NDDOTOnline" title="">
# <img alt="NDDOT Youtube" class="img-responsive" src="/assets/img/you-tube-mobile.png"/>
# </a>
# </span>
# <span class="mobile-icon">
# <a href="https://www.dot.nd.gov/govdelivery/landing.htm" title="">
# <img alt="NDDOT Email" class="img-responsive" src="/assets/img/email-mobile.png"/>
# </a>
# </span>
# <span class="mobile-icon">
# <a href="https://www.dot.nd.gov/search/" title="">
# <img alt="NDDOT Search" class="img-responsive" src="/assets/img/search-icon.png"/>
# </a>
# </span>
# </div>
# </div>
# <div class="navbar-collapse collapse navbar-collapsible"> <!--Added navbar-collapsible and removed navbar id prev targeted by button click-->
# <ul class="nav navbar-nav border-bottom-links">
# <li class="mobile-menu-links"><a href="/" title="Home">Home</a></li>
# <li class="mobile-menu-links"><a href="/public/about.htm" title="About Page">About</a></li>
# <li class="mobile-menu-links"><a href="/dotnet2/view/careers.aspx" title="Careers Page">Careers</a></li>
# <li class="mobile-menu-links"><a href="/public/contacts.htm" title="Contact">Contact</a></li>
# <li class="mobile-menu-links"><a href="/dotnet2/faq/faq.aspx" title="Get Answers">Get Answers</a></li>
# <li class="mobile-menu-links"><a href="/dotnet2/view/publications.aspx" title="Publications">Publications</a></li>
# <li class="mobile-menu-links"><a href="/dotnet2/view/forms.aspx" title="Forms">Forms</a></li>
# <li class="mobile-menu-links"><a href="/public/" title="public">Public</a></li>
# <li class="mobile-menu-links"><a href="/travel/" title="travel/roads">Travel/Roads</a></li>
# <li class="mobile-menu-links"><a href="/business/" title="business">Business</a></li>
# <li class="nav-no-link">Quick Links:</li>
# <li class="nav-ind-link mobile-menu-links"><a href="/divisions/driverslicense/driver.htm" title="Driver Page">Driver</a></li>
# <li class="nav-ind-link mobile-menu-links"><a href="/divisions/mv/vehicle.htm" title="Vehicle Page">Vehicle</a></li>
# <li class="nav-ind-link mobile-menu-links"><a href="/public/safety.htm" title="Safety Page">Safety</a></li>
# <li class="nav-ind-link mobile-menu-links"><a href="https://www.dot.nd.gov/travel-info/" title="Travel">Travel Information Map</a></li>
# <li class="nav-ind-link mobile-menu-links"><a href="/dotnet2/news/newsrelease.aspx" title="News Releases">News Releases</a></li>
# <li class="nav-ind-link mobile-menu-links"><a href="/dotnet2/view/publiccalendar.aspx" title="Calendar of Events">Calendar of Events</a></li>
# <li class="nav-ind-link mobile-menu-links"><a href="/divisions/civilrights/civilrights.htm" title="Civil Rights Program Areas">Civil Rights Program Areas</a></li>
# <li class="nav-ind-link mobile-menu-links"><a href="/business/maps.htm" title="NDDOT Maps">NDDOT Maps</a></li>
# <li class="nav-ind-link mobile-menu-links"><a href="https://apps.nd.gov/dot/dlts/dlos/scheduleWelcome.htm" title="Schedule Driver Test">Schedule Driver Test</a></li>
# <li class="nav-ind-link mobile-menu-links"><a class="external-exception" href="https://www.ventusappointment.com/Booking/Booking/Index/5KIDD4bc" title="Schedule Drivers License, Permit or Real ID">Schedule Drivers License, Permit or Real ID</a></li>
# <li class="nav-ind-link mobile-menu-links"><a href="/business/employees-partners.htm#dotemployees" title="DOT Employees">DOT Employees</a></li>
# <li class="nav-no-link">Director's Message</li>
# <li class="nav-ind-link mobile-menu-links"><a href="/divisions/exec/welcome.htm" title="Director Welcome Link">Welcome from the Director</a></li>
# <li class="mobile-menu-links hidden-xs"><a href="/travel-info/" title="Travel Information">Road Condition Information</a></li>
# <li class="mobile-menu-links hidden-sm hidden-md hidden-lg"><a href="/travelinfo/ndroads.htm" title="Travel Information">Mobile Travel Information</a></li>
# <li class="mobile-menu-links"><a href="https://visionzero.nd.gov/" title="Vision Zero: Zero fatalities. Zero excuses.">Vision Zero: Zero fatalities. Zero excuses.</a></li>
# <li class="mobile-menu-links"><a href="/govdelivery/landing.htm" title="GovDelivery - Subscribe to receive updates">Subscribe to receive Updates</a></li>
# <li class="mobile-menu-links"><a href="/public/mobile-apps.htm" title="Motor Vehicle App">NDDOT Mobile Apps</a></li>
# <li class="mobile-menu-links"><a href="/divisions/maintenance/511.htm" title="North Dakota 511">North Dakota 511</a></li>
# <li class="mobile-menu-links"><a href="/dotnet2/submitinfo/submitinfo.aspx?pageID=map-req" title="Request a Free North Dakota Road Map">Request a FREE North Dakota Road Map</a></li>
# </ul>
# </div><!--/.nav-collapse -->
# </nav>
# </div>
# </div>
# <!-- end of mobile banner. -->
# <nav aria-expanded="true" class="navbar-fixed-top navbar-fixed-top-special navbar-collapsible collapse in" style="position: fixed;">
# <!--  BEGIN ---- Row Header -->
# <div class="row header">
# <div class="col-md-12 col-sm-12 hidden-xs menu">
# <div class="row hidden-sm">
# <div class="top-nav-background pull-right">
# <div class="inline-block padding-left-50px padding-right-15px">
# <span class="follow-us">Follow Us: </span>
# <span class="social-icon">
# <a href="https://www.facebook.com/nddot" title="Facebook Page">
# <img alt="Facebook Icon" class="img-responsive" src="/assets/img/facebook-icon.png"/>
# </a>
# </span>
# <span class="social-icon">
# <a class="external-exception" href="https://www.linkedin.com/company/north-dakota-department-of-transportation?trk=ppro_cprof" title="LinkedIn Page">
# <img alt="LinkedIn Icon" class="img-responsive" src="/assets/img/linkedIn.png"/>
# </a>
# </span>
# <span class="social-icon">
# <a href="https://www.youtube.com/user/NDDOTOnline" title="Youtube Page">
# <img alt="Youtube Icon" class="img-responsive" src="/assets/img/youtube-icon.png"/>
# </a>
# </span>
# <span class="social-icon">
# <a href="https://www.flickr.com/photos/nddot/" title="Flickr Page">
# <img alt="Flickr Icon" class="img-responsive" src="/assets/img/flicker-icon.png"/>
# </a>
# </span>
# <span class="social-icon">
# <a href="https://www.dot.nd.gov/govdelivery/landing.htm" title="Email Feed">
# <img alt="Email Icon" class="img-responsive" src="/assets/img/mail-icon.png"/>
# </a>
# </span>
# </div>
# </div>
# </div>
# <div class="row header-content">
# <!--START homeheader.inc file-->
# <!--  BEGIN ---- ND BE LEGENDARY LOGO -->
# <div class="col-md-5 col-sm-5">
# <a href="/" title="NDDOT Home Page">
# <img alt="North Dakota Be Legendary. | Transportation" class="img-responsive visible-lg" src="/assets/img/legendary-logo/legendary-transportaion-logo-white-on-tran.png" style="padding:7px 7px 7px 7px;" title="North Dakota Be Legendary. | Transportation"/>
# <img alt="North Dakota Be Legendary. | Transportation" class="img-responsive visible-md" src="/assets/img/legendary-logo/legendary-transportaion-logo-white-on-tran.png" style="padding:7px 7px 7px 7px;;" title="North Dakota Be Legendary. | Transportation"/>
# <img alt="North Dakota Be Legendary. | Transportation" class="img-responsive visible-sm" src="/assets/img/legendary-logo/legendary-transportaion-logo-white-on-tran.png" style="padding:25px 7px 7px 7px;" title="North Dakota Be Legendary. | Transportation"/>
# </a>
# </div>
# <!--  END ---- ND BE LEGENDARY LOGO -->
# <!--  BEGIN ---- Rotating Banner -->
# <div class="col-md-4 col-sm-4 image-placeholder header-image-adjusted" style="padding:0px 0px 0px 0px;">
# <ul class="lightSlider lsImages">
# <li class="ls-text"><a href="https://www.dot.nd.gov/divisions/safety/streetskills/winterdriving.htm" target="_blank"><img alt="ice and snow take it slow" class="img-responsive centered-image headerImage" src="/assets/img/banner/ice-snow.jpg" style="padding-top: 7px; margin-left: auto; margin-right: auto;"/></a></li>
# </ul>
# </div>
# <!--  END ---- Rotating Banner -->
# <!--  BEGIN ---- NDDOT LOGO -->
# <div class="col-md-3 col-sm-3">
# <a href="/" title="NDDOT Home Page">
# <img alt="North Dakota Department of Transportation" class="img-responsive visible-lg" src="/assets/img/media-download/nddot-logos/nddot-logo-white.png" style="padding:18px 22px 12px 22px;" title="North Dakota Department of Transportation"/>
# <img alt="North Dakota Department of Transportation" class="img-responsive visible-md" src="/assets/img/media-download/nddot-logos/nddot-logo-white.png" style="padding:20px 10px 10px 10px;" title="North Dakota Department of Transportation"/>
# <img alt="North Dakota Department of Transportation" class="img-responsive visible-sm" src="/assets/img/media-download/nddot-logos/nddot-logo-white.png" style="padding:32px 0px 0px 0px;" title="North Dakota Department of Transportation"/>
# </a>
# </div>
# <!--  END ---- NDDOT LOGO -->
# <!--END homeheader.inc SECTION -->
# </div>
# </div>
# <!--  END ---- Row Header -->
# <div class="bb-bottom-tab col-xs-12 hidden-xs hidden-sm">
# <form action="/search/index.htm" class="gcse" id="cse-search-box" method="get">
# <div class="form-inline pull-right">
# <div class="form-group">
# <script src="/assets/js/google-search-utils.js" type="text/javascript"></script>
# <label class="sr-only" for="search">Search:</label>
# <div class="input-group padding-top-2px">
# <input class="form-control searchbox" id="search" name="query" placeholder="Search..." size="15" style="padding: 3px 9px; height: 25px;" type="text" value=""/>
# <div class="input-group-addon" onclick="createGoogleSearchCookie(window.location.href); document.getElementById('cse-search-box').submit();" style="padding: 3px 9px; height: 25px;"><span aria-hidden="true" class="glyphicon glyphicon-search"></span><input class="hidden" name="" type="submit" value=""/>
# </div>
# </div>
# </div>
# </div>
# </form>
# <p class="pull-right padding-right-5px bottom-tab-navigation">
# <a class="active" href="/" title="Home Page">Home</a> | <a href="/public/about.htm" title="About Page">About</a> | <a href="/dotnet2/view/careers.aspx" title="Careers Page">Careers</a> | <a href="/public/contacts.htm" title="Contact Page">Contact Us</a> | <a href="/dotnet2/view/faq.aspx" title="Frequently Asked Questions Page">Get Answers</a> | <a href="/dotnet2/view/publications.aspx" title="Publications Page">Publications</a> | <a href="/dotnet2/view/forms.aspx" title="Forms Page">Forms</a>
# </p>
# </div>
# </div>
# </nav>
# <div class="row visible-xs mobile-message-sub">
# <div class="col-xs-12">
# <ul class="lightSlider lsMobile">
# <li>
# <a class="mobile-message-sub visible-xs text-center" href="https://www.dot.nd.gov/divisions/safety/streetskills/constructionzones.htm" style="color: #ff7e00">
# 					Winter Driving<br/>
# <span style="color: #ffffff">Tips for winter driving.</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="row child-content" role="main">
# <div class="main-container">
# <script type="text/javascript">
#     var resetStartDate = "";
#     var resetEndDate = "";
#     var prevYearStart = "";
#     var prevYearEnd = "";
#
#     $(document).ready(function() {
#         resetStartDate = '01/01/2019';
#         resetEndDate = '04/18/2019';
#         prevYearStart = '01/01/2018';
#         prevYearEnd = '01/01/2019';
#     });
# </script>
# <div class="publicsearch">
# <form action="/dotnet/news/Public/Index" id="PublicForm" method="post"> <fieldset>
# <legend>News Releases</legend>
# <input name="__RequestVerificationToken" type="hidden" value="JUiPYpAx5QgOQ-PnXSw_ycb0i1OwmnRwenZbAeL4ATQPsr8fe2Ce-zSL1npUcgCBW2QrbRZn8IP5drNd7NO-y17zgNP1FZmEh1zJc3mYgFY1"/>
# <div class="form-horizontal margin-left-10">
# <div class="form-label pull-left col-xs-2 col-sm-2">
# <label class="control-label col-xs-2" for="CurrentCategoryId">Category: </label>
# </div>
# <div class="col-xs-10 col-sm-4 form-editor">
# <select class="form-control input-sm margin-right-10" data-val="true" data-val-number="The field Category:  must be a number." data-val-required="The Category:  field is required." id="CurrentCategoryId" name="CurrentCategoryId"><option selected="selected" value="-1">All Categories</option>
# <option value="1">Public Meetings</option>
# <option value="2">Road Conditions</option>
# <option value="3">Construction</option>
# <option value="4">Safety</option>
# <option value="5">Other</option>
# </select>
# </div>
# <div class="form-label pull-left col-xs-2 col-sm-2">
# <label class="control-label col-xs-2" for="TitleSearchWords">Title/Description: </label>
# </div>
# <div class="col-xs-10 col-sm-4 form-editor">
# <input class="form-control margin-right-10 col-xs-3 text-box single-line" id="TitleSearchWords" name="TitleSearchWords" type="text" value=""/>
# </div>
# <div class="pull-left col-xs-10 col-sm-4 form-buttons">
# <input class="btn-xs" id="btnSearch" name="btnSearch" type="submit" value="Search"/>
# <input class="btn-xs" id="btnReset" name="btnReset" type="button" value="Clear"/>
# <input data-val="true" data-val-date="The field StartDate must be a date." id="StartDate" name="StartDate" type="hidden" value="1/1/2019 12:00:00 AM"/>
# <input data-val="true" data-val-date="The field EndDate must be a date." id="EndDate" name="EndDate" type="hidden" value="4/18/2019 2:00:01 PM"/>
# <input data-val="true" data-val-number="The field DistrictId must be a number." data-val-required="The DistrictId field is required." id="DistrictId" name="DistrictId" type="hidden" value="0"/>
# </div>
# <br class="clearfix"/>
# </div>
# </fieldset>
# <div class="col-xs-9 publicsearch-pickyear">
# <a class="external-exception" href="javascript:void(0)" id="evtLastYear">2018 Releases</a> </div>
# <br class="clearfix"/>
# </form>
# </div>
# <div class="publicsearch-grid">
# <div class="col-xs-12 table-responsive">
# <table class="table table-bordered table-striped table-condensed">
# <caption>Table containing a list of news releases.</caption>
# <thead>
# <tr>
# <th class="control-label" style="width: 12%;">Category</th>
# <th>Headline</th>
# <th>Publish Date</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Public Meetings</td>
# <td><a href="/dotnet/news/Public/View/8337" target="_blank">Public Input Meeting on April 25, to discuss proposed improvements to Main Street in Mandan</a></td>
# <td style="white-space: nowrap;">4/18/2019 11:42 AM</td>
# </tr>
# <tr>
# <td>Construction</td>
# <td><a href="/dotnet/news/Public/View/8336" target="_blank">Construction starts Monday on I-29 near exit 44</a></td>
# <td style="white-space: nowrap;">4/18/2019 10:18 AM</td>
# </tr>
# <tr>
# <td>Road Conditions</td>
# <td><a href="/dotnet/news/Public/View/8335" target="_blank">Water receded on I-29, 20 miles north of Grand Forks</a></td>
# <td style="white-space: nowrap;">4/16/2019 10:39 AM</td>
# </tr>
# <tr>
# <td>Road Conditions</td>
# <td><a href="/dotnet/news/Public/View/8334" target="_blank">ND Hwy 5 temporarily closed from I-29 to the Red River</a></td>
# <td style="white-space: nowrap;">4/15/2019 3:58 PM</td>
# </tr>
# <tr>
# <td>Road Conditions</td>
# <td><a href="/dotnet/news/Public/View/8333" target="_blank">Water on I-29 north of Grand Forks</a></td>
# <td style="white-space: nowrap;">4/14/2019 9:45 AM</td>
# </tr>
# <tr>
# <td>Road Conditions</td>
# <td><a href="/dotnet/news/Public/View/8332" target="_blank">Water on I-29 north of Grand Forks</a></td>
# <td style="white-space: nowrap;">4/12/2019 6:50 PM</td>
# </tr>
# <tr>
# <td>Road Conditions</td>
# <td><a href="/dotnet/news/Public/View/8331" target="_blank">Southbound on ramp on I-29 Exit 164 north of Grand Forks temporarily closed</a></td>
# <td style="white-space: nowrap;">4/12/2019 3:19 PM</td>
# </tr>
# <tr>
# <td>Road Conditions</td>
# <td><a href="/dotnet/news/Public/View/8330" target="_blank">I-29 OPEN from Grand Forks to Canadian border  </a></td>
# <td style="white-space: nowrap;">4/12/2019 12:00 PM</td>
# </tr>
# <tr>
# <td>Road Conditions</td>
# <td><a href="/dotnet/news/Public/View/8329" target="_blank">I-29 OPEN from Fargo to SD border; Hwy. 13 OPEN  </a></td>
# <td style="white-space: nowrap;">4/12/2019 10:00 AM</td>
# </tr>
# <tr>
# <td>Road Conditions</td>
# <td><a href="/dotnet/news/Public/View/8328" target="_blank">No Travel Advisory lifted for areas in south central ND</a></td>
# <td style="white-space: nowrap;">4/12/2019 8:58 AM</td>
# </tr>
# <tr>
# <td>Road Conditions</td>
# <td><a href="/dotnet/news/Public/View/
# </ul>
# </div>
# <div class="text-center">
#                 Copyright © <span id="copyrightyear"></span>. North Dakota Department of Transportation. All Rights Reserved.<br/>
#                 Questions or Comments? <a href="/dotnet2/submitinfo/submitinfo.aspx?pageID=questions" title="Contact DOT">Contact NDDOT</a><br/>
# <a href="/viewerinstructions.htm" title="Document View and Download Instructions">Document View and Download Instructions</a>
# </div>
# </footer>
# </div>
# </div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.2/jquery.min.js"></script>
# <script src="/assets/js/bootstrap.min.js"></script>
# <script src="/assets/js/dotspecificjquery.js?ver=1.5"></script>
# <script src="/assets/js/jquery-1.10.2.js"></script>
# <!-- Copyright Year -->
# <script>
# 	var d = new Date();
# 	document.getElementById('copyrightyear').innerHTML = d.getFullYear();
# </script>
# <!-- End Copyright Year -->
# <!-- Google Analytics -->
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#   ga('create', 'UA-8903059-2', 'auto');
#   ga('require', 'displayfeatures');
#   ga('send', 'pageview');
#
# </script>
# <!-- End Google Analytics -->
# <!-- Google Tag Manager -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-KNZXJK" style="display:none;visibility:hidden" title="Google Tag Manager" width="0"></iframe></noscript>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-KNZXJK');</script>
# <!-- End Google Tag Manager -->
# <!-- Siteimprove Analytics -->
# <script type="text/javascript">
# /*<![CDATA[*/
# (function() {
# var sz = document.createElement('script'); sz.type = 'text/javascript'; sz.async = true;
# sz.src = '//us1.siteimprove.com/js/siteanalyze_1580.js';
# var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(sz, s);
# })();
# /*]]>*/
# </script>
# <!-- End Siteimprove Analytics -->
# <script src="/assets/js/lightslider.js"></script>
# <!-- end of footer. -->
# <script src="https://cdn.datatables.net/1.10.15/js/jquery.dataTables.min.js"></script>
# <script src="https://cdn.datatables.net/1.10.15/js/dataTables.bootstrap.min.js"></script>
# </div>
# </div>
# <script src="/dotnet/news/Scripts/jquery.validate.js"></script>
# <script src="/dotnet/news/Scripts/jquery.validate.unobtrusive.js"></script>
# <script src="/dotnet/news/Scripts/datatables.min.js"></script>
# <script src="/dotnet/news/Scripts/ViewSpecific/public-search.js"></script>
# <script>
# 		$(document).ready(function () {
# 			$('.table').DataTable({
# 				"dom": 'rtip', /*default: lfrtip - f creates search field, p creates paging options, will handle manually*/
# 				"paging": true,
# 				"iDisplayLength": 50,
# 				"bInfo": false,
# 				"aaSorting": [], //prevent automatic sorting by first column
# 				"columnDefs": [
# 					{ "type": "date", "targets": -1 }
# 				]
# 			});
#
# 			$("a").each(function () {
# 				var fullHref = $(this).prop("href");
# 				if ((fullHref.toLowerCase().indexOf("localhost") >= 0)) {
# 					$(this).removeClass("external-site");
# 				}
# 				$(this).attr("href", fullHref);
# 			});
#
# 		});
# 	</script>
# <noscript>
# <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-KNZXJK" style="display:none;visibility:hidden" title="Google Tag Manager" width="0"></iframe>
# </noscript>
# </body>
# </html>

# %%
table = soup.find('table', {'class': "table"})

# %%
print(table)
# Out:
# <table class="table table-bordered table-striped table-condensed">
# <caption>Table containing a list of news releases.</caption>
# <thead>
# <tr>
# <th class="control-label" style="width: 12%;">Category</th>
# <th>Headline</th>
# <th>Publish Date</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Public Meetings</td>
# <td><a href="/dotnet/news/Public/View/8337" target="_blank">Public Input Meeting on April 25, to discuss proposed improvements to Main Street in Mandan</a></td>
# <td style="white-space: nowrap;">4/18/2019 11:42 AM</td>
# </tr>
# <tr>
# <td>Construction</td>
# <td><a href="/dotnet/news/Public/View/8336" target="_blank">Construction starts Monday on I-29 near exit 44</a></td>
# <td style="white-space: nowrap;">4/18/2019 10:18 AM</td>
# </tr>
# <tr>
# <td>Road Conditions</td>
# <td><a href="/dotnet/news/Public/View/
eastern North Dakota</a></td>
# <td style="white-space: nowrap;">1/8/2019 7:40 AM</td>
# </tr>
# <tr>
# <td>Road Conditions</td>
# <td><a href="/dotnet/news/Public/View/8167" target="_blank">Travel Alert issued for northeastern North Dakota</a></td>
# <td style="white-space: nowrap;">1/6/2019 7:45 PM</td>
# </tr>
# <tr>
# <td>Public Meetings</td>
# <td><a href="/dotnet/news/Public/View/8166" target="_blank">Public Input Meeting January 10, 2019 to discuss proposed roadway and structure construction along 64th Avenue South in Fargo </a></td>
# <td style="white-space: nowrap;">1/3/2019 2:18 PM</td>
# </tr>
# <tr>
# <td>Safety</td>
# <td><a href="/dotnet/news/Public/View/8165" target="_blank">2,430 citations issued during Click it or Ticket enforcement campaign</a></td>
# <td style="white-space: nowrap;">1/2/2019 10:17 AM</td>
# </tr>
# </tbody>
# </table>

# %%
teams = []
for row in table.find_all('tr')[1:]:
    team = {}
    team['alert_type'] = row.find('td').text
    team['headline'] = row.find('a').text
    team['url'] = row.find('a').attrs
    teams.append(team)

df_nd = pd.DataFrame(teams)

# %%
df_nd['url'] = df_nd['url'].astype(str)

# %%
df_nd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 3 columns):
# alert_type    173 non-null object
# headline      173 non-null object
# url           173 non-null object
# dtypes: object(3)
# memory usage: 4.1+ KB

# %%
df_nd['url'] = df_nd['url'].str.replace("{'href': '", "")

# %%
df_nd['url'] = df_nd['url'].str.replace("', 'target': '_blank'}", "")

# %%
df_nd.head()
# Out:
#         alert_type  \
# 0  Public Meetings
# 1     Construction
# 2  Road Conditions
# 3  Road Conditions
# 4  Road Conditions
#
#                                                                                       headline  \
# 0  Public Input Meeting on April 25, to discuss proposed improvements to Main Street in Mandan
# 1                                              Construction starts Monday on I-29 near exit 44
# 2                                         Water receded on I-29, 20 miles north of Grand Forks
# 3                                       ND Hwy 5 temporarily closed from I-29 to the Red River
# 4                                                           Water on I-29 north of Grand Forks
#
#                              url
# 0  /dotnet/news/Public/View/8337
# 1  /dotnet/news/Public/View/8336
# 2  /dotnet/news/Public/View/8335
# 3  /dotnet/news/Public/View/8334
# 4  /dotnet/news/Public/View/8333

# %% [markdown]
# The site contains alerts for more than just road closures.  Some are for meetings, construction alerts, etc.  We do not want to include these alerts in our set, so we will remove them, leaving only road alerts.

# %%
mask = df_nd['alert_type'] == 'Road Conditions'
df_nd_conditions = df_nd[mask]

# %%
df_nd_conditions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 134 entries, 2 to 170
# Data columns (total 3 columns):
# alert_type    134 non-null object
# headline      134 non-null object
# url           134 non-null object
# dtypes: object(3)
# memory usage: 4.2+ KB

# %%
df_nd_conditions.head()
# Out:
#         alert_type  \
# 2  Road Conditions
# 3  Road Conditions
# 4  Road Conditions
# 5  Road Conditions
# 6  Road Conditions
#
#                                                                       headline  \
# 2                         Water receded on I-29, 20 miles north of Grand Forks
# 3                       ND Hwy 5 temporarily closed from I-29 to the Red River
# 4                                           Water on I-29 north of Grand Forks
# 5                                           Water on I-29 north of Grand Forks
# 6  Southbound on ramp on I-29 Exit 164 north of Grand Forks temporarily closed
#
#                              url
# 2  /dotnet/news/Public/View/8335
# 3  /dotnet/news/Public/View/8334
# 4  /dotnet/news/Public/View/8333
# 5  /dotnet/news/Public/View/8332
# 6  /dotnet/news/Public/View/8331

# %%
full_text_list = []
for i in df_nd_conditions.url: 
    url_base = 'https://www.dot.nd.gov'
    url_combine = url_base + i
    res = requests.get(url_combine)
    soup = BeautifulSoup(res.content, 'lxml')
    full_text = soup.find('div', {'class': "display-content"}).text.strip()
    full_text_list.append(full_text)
print(full_text_list)
# Out:
# ['Water has receded on northbound I-29 approximately 20 miles north of Grand Forks. The roadway is open to two lanes of traffic and speeds are normal.\nMotorists should drive with caution as flooding continues to affect area highways and should check road conditions before traveling due to rapidly changing conditions. For road information, call 511 from any type of phone or go to the website: www.dot.nd.gov.\nFluctuating water levels make it difficult to predict when and where water will go over a roadway or recede from the roadway. NDDOT warns motorists that driving through water is dangerous and should not drive around barricades or into flooded areas as vehicles that leave the roadway may become immersed in high water.\nFor statewide flooding information, please go to\xa0https://ndresponse.gov/', 'The North Dakota Department of Transportation has temporarily\xa0closed\xa0ND Hwy 5 from I-29 to the Red River (Exit 203 near Joliette) due to water on the roadway. This road will remain closed until river levels recede. Motorists will need to take an alternate route.\nThe NDDOT urges motorists to check road conditions before traveling due to rapidly changing conditions. Fluctuating water levels make it difficult to predict when and where water will go over a roadway or recede from the roadway. For updated road information, call 511 from any type of phone or go to the Travel Information Map on our website at\xa0www.dot.nd.gov.\nFor statewide flooding information, please go to\xa0https://ndresponse.gov/', 'There is water on the southbound lanes of I-29 approximately 25 miles north of Grand Forks. The roadway is reduced to one lane. Traffic is allowed with traffic speeds reduced and traffic control is in place.\nNDDOT encourages motorists to check road conditions before traveling. For updated road information, call 511 from any type of phone or go to the Travel Information Map on our website at www.dot.nd.gov', 'There is water on the northbound lanes of I-29 approximately 20 miles north of Grand Forks. The roadway is reduced to one lane. Traffic is allowed with traffic speeds reduced and traffic control is in place.\nNDDOT encourages motorists to check road conditions before traveling. For updated road information, call 511 from any type of phone or go to the Travel Information Map on our website at www.dot.nd.gov.', 'The North Dakota Department of Transportation has temporarily\xa0closed\xa0the southbound on ramp on I-29 Exit 164, approximately 20 miles north of Grand Forks, due to water on the roadway. The northbound off ramp on I-29 at Exit 164 remains closed. The ramps will be closed until river levels recede. Motorists will need to take an alternate route.\nThe NDDOT urges motorists to check road conditions before traveling due to rapidly changing conditions. Fluctuating water levels make it difficult to predict when and where water will go over a roadway or recede from the roadway. For updated road information, call 511 from any type of phone or go to the Travel Information Map on our website at\xa0www.dot.nd.gov.\nFor statewide flooding information, please go to\xa0https://ndresponse.gov/', 'The North Dakota Department of Transportation (NDDOT) along with the North Dakota Highway Patrol (NDHP) have OPENED I-29 from Grand Forks to the Canadian border. According to South Dakota DOT, I-29 is now open at the North Dakota border.\nA Travel Alert is in effect for all of eastern North Dakota due to compacted snow and ice on the roadways. Cities included in the Travel Alert are Jamestown, Valley City, Edgeley, Ellendale, Wahpeton, Fargo, Grand Forks and surrounding areas. A Travel Alert means motorists can travel, but should be aware of winter driving conditions and should slow down. \xa0\nThe NDDOT is also urging motorists to use caution if traveling in eastern North Dakota because due to current flood conditions this spring, there is extra concern for motorists due to water filled ditches along many roadways. Motorists should slow  ...

# %%
df_nd_conditions['post'] = full_text_list
# Out:
# C:\Users\phill\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_nd_conditions.head()
# Out:
#         alert_type  \
# 2  Road Conditions
# 3  Road Conditions
# 4  Road Conditions
# 5  Road Conditions
# 6  Road Conditions
#
#                                                                       headline  \
# 2                         Water receded on I-29, 20 miles north of Grand Forks
# 3                       ND Hwy 5 temporarily closed from I-29 to the Red River
# 4                                           Water on I-29 north of Grand Forks
# 5                                           Water on I-29 north of Grand Forks
# 6  Southbound on ramp on I-29 Exit 164 north of Grand Forks temporarily closed
#
#                              url  \
# 2  /dotnet/news/Public/View/8335
# 3  /dotnet/news/Public/View/8334
# 4  /dotnet/news/Public/View/8333
# 5  /dotnet/news/Public/View/8332
# 6  /dotnet/news/Public/View/8331
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   post
# 2  Water has receded on northbound I-29 approximately 20 miles north of Grand Forks. The roadway is open to two lanes of traffic and speeds are normal.\nMotorists should drive with caution as flooding continues to affect area highways and should check road conditions before traveling due to rapidly changing conditions. For road information, call 511 from any type of phone or go to the website: www.dot.nd.gov.\nFluctuating water levels make it difficult to predict when and where water will go over a roadway or recede from the roadway. NDDOT warns motorists that driving through water is dangerous and should not drive around barricades or into flooded areas as vehicles that leave the roadway may become immersed in high water.\nFor statewide flooding information, please go to https://ndresponse.gov/
# 3                                                                                                          The North Dakota Department of Transportation has temporarily closed ND Hwy 5 from I-29 to the Red River (Exit 203 near Joliette) due to water on the roadway. This road will remain closed until river levels recede. Motorists will need to take an alternate route.\nThe NDDOT urges motorists to check road conditions before traveling due to rapidly changing conditions. Fluctuating water levels make it difficult to predict when and where water will go over a roadway or recede from the roadway. For updated road information, call 511 from any type of phone or go to the Travel Information Map on our website at www.dot.nd.gov.\nFor statewide flooding information, please go to https://ndresponse.gov/
# 4                                                                                                                                                                                                                                                                                                                                                                                                            There is water on the southbound lanes of I-29 approximately 25 miles north of Grand Forks. The roadway is reduced to one lane. Traffic is allowed with traffic speeds reduced and traffic control is in place.\nNDDOT encourages motorists to check road conditions before traveling. For updated road information, call 511 from any type of phone or go to the Travel Information Map on our website at www.dot.nd.gov
# 5                                                                                                                                                                                                                                                                                                                                                                                                           There is water on the northbound lanes of I-29 approximately 20 miles north of Grand Forks. The roadway is reduced to one lane. Traffic is allowed with traffic speeds reduced and traffic control is in place.\nNDDOT encourages motorists to check road conditions before traveling. For updated road information, call 511 from any type of phone or go to the Travel Information Map on our website at www.dot.nd.gov.
# 6                         The North Dakota Department of Transportation has temporarily closed the southbound on ramp on I-29 Exit 164, approximately 20 miles north of Grand Forks, due to water on the roadway. The northbound off ramp on I-29 at Exit 164 remains closed. The ramps will be closed until river levels recede. Motorists will need to take an alternate route.\nThe NDDOT urges motorists to check road conditions before traveling due to rapidly changing conditions. Fluctuating water levels make it difficult to predict when and where water will go over a roadway or recede from the roadway. For updated road information, call 511 from any type of phone or go to the Travel Information Map on our website at www.dot.nd.gov.\nFor statewide flooding information, please go to https://ndresponse.gov/

# %%
#df_nd_conditions.to_csv('./data/nd_511.csv')

# %% [markdown]
# # Minnesota DOT 511 Web scrapping  <a class="anchor" id="fifth-bullet"></a>

# %% [markdown]
# In this section, we will scrape the MN 511 DOT site for road closure alerts.

# %%
url = 'https://lb.511mn.org//mnlb/roadreports/menu.jsf?view=state&text=m&textOnly=true&current=true'

res = requests.get(url)

# %%
res.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(res.content, 'lxml')

# %%
soup.find()
# Out:
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <title>Minnesota Department of Transportation - Low Bandwidth Web - Critical Alerts</title>
# <link href="/mnlb/css/crc-common.css" rel="stylesheet"/>
# <link href="/mnlb/css/mediumtext.css?2.2.10" rel="stylesheet"/>
# <link href="/mnlb/css/base.css?2.2.10" rel="stylesheet"/>
# <link href="/mnlb/css/current.css?2.2.10" rel="stylesheet"/>
# <link href="/mnlb/css/panels-largeright.css?2.2.10" rel="stylesheet"/>
# <link href="/mnlb/css/crc-event.css?2.2.10" rel="stylesheet"/>
# <script src="/mnlb/js/lbweb.js?2.2.10" type="text/javascript"></script>
# </head>
# <body>
# <style type="text/css">
#       a#skip
#       {
#          position: absolute;
#          left: auto;
#          top: -1000px;
#          width: 1px;
#          height: 1px;
#          overflow: hidden;
#       }
#       a:active#skip, a:focus#skip
#       {
#          position: static;
#          width: auto;
#          height: auto;
#       }
#    </style>
# <div class="pageWidth">
# <a href="#mainContent" id="skip" onclick="document.getElementById('mainContent').focus();">Skip Navigation</a>
# <style type="text/css">
#       .banner-item{ padding:3px; color:white; }
#       .banner-item a{ color:white; text-decoration:none; }
#    </style>
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td align="center" bgcolor="#FFFFFF" class="body" height="40" valign="bottom">
# <!-- This is for Winter Driving Season: Octoberish - Aprilish -->
# <!-- &lt;img id="banner" src="/mnlb/images/header/background_winter_2016.png" style="border-style: none" alt="MNDOT Banner" usemap="#banner"/&gt; -->
# <!-- This is for the rest of the year: Aprilish - Octoberish -->
# <img alt="MNDOT Banner" id="banner" src="/mnlb/images/header/background2.png" style="border-style: none" usemap="#banner"/>
# <map id="#banner" name="banner">
# <area alt="MN DOT" coords="0,0,328,79" href="http://www.dot.state.mn.us/" shape="rect" title="MN DOT"/>
# <area alt="511 Traveler Information" coords="811,1,887,56" href="http://www.511mn.org/" shape="rect" title="511 Traveler Information"/>
# </map>
# </td>
# </tr>
# </table>
# <meta content="app-id=664709236" name="apple-itunes-app"/>
# <div style="position: absolute; display: block; height: 84px; width: 900px; top: 68px; left: 0px; font-size: .8em;">
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td align="right" bgcolor="transparent" style="padding:5px;">
# <span class="banner-item"><a href="/mnlb/511info.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?view=state&amp;text=m&amp;textOnly=true"><b><i>NEED HELP?</i></b></a></span>
# <span class="banner-item">|</span>
# <span class="banner-item"><a href="https://tr.511mn.org" target="_blank">Truckers' Info</a></span>
# <!--&lt;span class="banner-item"&gt;|&lt;/span&gt;
#                &lt;span class="banner-item"&gt;&lt;a href="http://www.dot.state.mn.us/tmc/trafficinfo/traffic.html" target="_blank"&gt;Metro Traffic Map&lt;/a&gt;&lt;/span&gt;TGWEB-1440-->
# <span class="banner-item">|</span>
# <span class="banner-item"><a href="https://hb.511mn.org" target="_blank">HB Version</a></span>
# <span class="banner-item">|</span>
# <span class="banner-item"><a href="/mnlb/links.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?view=state&amp;text=m&amp;textOnly=true">Links</a></span>
# <span class="banner-item">|</span>
# <span class="banner-item"><a href="http://www.dot.state.mn.us/information/talk.html" target="_blank">Contact MnDOT</a></span>
# </td>
# </tr>
# </table>
# </div>
# <script type="text/javascript">
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-44124103-14']);
#   _gaq.push(['_trackPageview']);
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
# </script>
# </div>
# <div class="banner pageWidth" style="position:relative;">
# <table cellpadding="0" cellspacing="0" class="pageWidth">
# <tr>
# <td class="textSizeTd">
# <div class="bannerContent">Text Size
#                   <a class="textSizeSmall undecoratedLink" href="/mnlb/roadreports/menu.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?text=s&amp;view=state&amp;textOnly=true&amp;current=true">A</a><a class="textSizeMedium undecoratedLink" href="/mnlb/roadreports/menu.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?text=m&amp;view=state&amp;textOnly=true&amp;current=true">A</a><a class="textSizeLarge undecoratedLink" href="/mnlb/roadreports/menu.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?text=l&amp;view=state&amp;textOnly=true&amp;current=true">A</a>
# </div>
# </td>
# <td class="textOnlyTd">
# <div class="bannerContent"><a class="undecoratedLink" href="/mnlb/roadreports/menu.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?textOnly=false&amp;view=state&amp;text=m&amp;current=true">Text and Map</a>
# </div>
# </td>
# <td>
# <div><marquee id="j_idt240" onmouseout="if (this.start){this.start();} else {this.setAttribute('scrollamount', '3 ');};" onmouseover="if (this.stop){this.stop();} else {this.setAttribute('scrollamount','0');};" scrollamount="3" scrolldelay="5"><span class="scrollingBannerItem">There are closures or blockages on</span><a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A10&amp;view=state&amp;text=m&amp;textOnly=true" style="padding-left:.5em;">MN 1</a>,<a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A43&amp;view=state&amp;text=m&amp;textOnly=true" style="padding-left:.5em;">MN 19</a>,<a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A130&amp;view=state&amp;text=m&amp;textOnly=true" style="padding-left:.5em;">MN 41</a>,<a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A147&amp;view=state&amp;text=m&amp;textOnly=true" style="padding-left:.5em;">MN 60</a>,<a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A154&amp;view=state&amp;text=m&amp;textOnly=true" style="padding-left:.5em;">MN 67 (2 reports)</a>,<a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A160&amp;view=state&amp;text=m&amp;textOnly=true" style="padding-left:.5em;">MN 74</a>,<a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A201&amp;view=state&amp;text=m&amp;textOnly=true" style="padding-left:.5em;">US 75 (3 reports)</a>,<a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A177&amp;view=state&amp;text=m&amp;textOnly=true" style="padding-left:.5em;">MN 93</a>,<a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A178&amp;view=state&amp;text=m&amp;textOnly=true" style="padding-left:.5em;">MN 95</a>,<a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A53&amp;view=state&amp;text=m&amp;textOnly=true" style="padding-left:.5em;">MN 220</a>,<a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A113&amp;view=state&amp;text=m&amp;textOnly=true" style="padding-left:.5em;">MN 317</a></marquee>
# </div>
# </td>
# </tr>
# </table>
# </div>
# <div style="position:relative;">
# <div class="menuLeftPanel">
# <div class="breadcrumbs">
# <span class="panelTitle"> </span>
# <a href="#mainContent" id="mainContent" name="mainContent" tabindex="-1"> </a>
#          </div>
# <div class="menuPanelContent">
# <!--@elvariable id="winterDrivingPage" type="java.lang.String"-->
# <!--@elvariable id="roadReportsPage" type="java.lang.String"-->
# <!--@elvariable id="trafficSpeedsPage" type="java.lang.String"-->
# <!--@elvariable id="selectedTrafficRegion" type="java.lang.String"-->
# <!--@elvariable id="truckReportsPage" type="java.lang.String"-->
# <!--@elvariable id="rwisStationsPage" type="java.lang.String"-->
# <!--@elvariable id="mountainPassesPage" type="java.lang.String"-->
# <!--@elvariable id="dmsSignsPage" type="java.lang.String"-->
# <div class="panelTitle">
# <a href="#mainContent" id="mainContent" tabindex="-1"> </a>
#       Menu
#    </div>
# <table border="0" cellpadding="3" cellspacing="5">
# <!-- This is for Winter Driving Season: Octoberish - Aprilish -->
# <tr>
# <td valign="middle"><a class="panelTitle" href="/mnlb/winterdriving/routeselect.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?view=state&amp;text=m&amp;textOnly=true">Winter Driving</a></td>
# </tr>
# <!-- End of Winter Driving Season section -->
# <tr>
# <td valign="middle"><a class="panelTitle" href="/mnlb/roadreports/routeselect.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?view=state&amp;text=m&amp;textOnly=true&amp;current=true">Road Reports</a></td>
# </tr>
# <tr>
# <td valign="middle"><a class="panelTitle" href="/mnlb/truckreports/routeselect.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?view=state&amp;text=m&amp;textOnly=true&amp;current=true">Restrictions</a></td>
# </tr>
# <!-- Plow Cameras enabled for winter   -->
# <!-- end of plow cams -->
# <tr>
# <td valign="middle"><a class="panelTitle" href="/mnlb/rwisstations/routeselect.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?view=state&amp;text=m&amp;textOnly=true">Weather Stations</a></td>
# </tr>
# </table>
# </div>
# </div>
# <div class="pageMainContentRightPanel">
# <div class="pageTitle panelTitle" id="rptitle">
#          Critical Alerts—Statewide
#
#          </div>
# <script src="/mnlb/js/crc-texttruncation.js?2.2.10" type="text/javascript"></script>
# <script type="text/javascript">
#             fitTextToElement( 'rptitle' );
#          </script>
# <div class="pageMainContent">
# <div class="panelTitle paddingBottom">Statewide</div>
# <div onmouseout="removeHighlight( 'CARS4-13832' );" onmouseover="highlight( 'CARS4-13832' );"><table class="reportTitleCritical" style="width:100%">
# <tbody>
# <tr>
# <td class="verticalAlignMiddle"></td>
# <td class="verticalAlignMiddle fullWidth">
# <div><a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A43&amp;view=state&amp;text=m&amp;textOnly=true">MN 19: Flooding.</a>
# </div></td>
# </tr>
# </tbody>
# </table>
# <div class="reportBody">
# <div id="list-entry-CARS4-13832">
# <div id="CARS4-13832-less" style="display:block;">
# <div class="reportBodyText">
# <!-- JSF quirk: without both of these being wrapped in something like a span, there is no space between them -->
# <span class="delay-description"></span>
# <span>Between MN 93; North 5th Street and US 169 (near Henderson). Look out for flooding. The road is closed.</span>
# </div>
# <div class="reportMore"><a href="#" onclick="showMore( 'CARS4-13832' )">More</a>
# </div>
# </div>
# <div id="CARS4-13832-more" style="display:none;">
# <div class="reportBodyText">
# <!-- JSF quirk: without both of these being wrapped in something like a span, there is no space between them -->
# <span class="delay-description"></span>
# <span>Between MN 93; North 5th Street and US 169 (near Henderson). Look out for flooding. The road is closed. <br/><br/><i>Web Comment:</i> Detour where possible</span>
# </div>
# <!-- Vox events include their own 'Posted by' HTML, so we shouldn't show 'Last updated' text in that case --><div class="reportBodyText">Last updated on March 19</div>
# <div class="reportMore"><a href="#" onclick="showLess( 'CARS4-13832' )">Less</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div onmouseout="removeHighlight( 'CARS4-13799' );" onmouseover="highlight( 'CARS4-13799' );"><table class="reportTitleCritical" style="width:100%">
# <tbody>
# <tr>
# <td class="verticalAlignMiddle"></td>
# <td class="verticalAlignMiddle fullWidth">
# <div><a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A177&amp;view=state&amp;text=m&amp;textOnly=true">MN 93: Flooding.</a>
# </div></td>
# </tr>
# </tbody>
# </table>
# <div class="reportBody">
# <div id="list-entry-CARS4-13799">
# <div id="CARS4-13799-less" style="display:block;">
# <div class="reportBodyText">
# <!-- JSF quirk: without both of these being wrapped in something like a span, there is no space between them -->
# <span class="delay-description"></span>
# <span>Between US 169 (Le Sueur) and MN 19; North 5th Street (Henderson). Look out for flooding. The road is closed.</span>
# </div>
# <div class="reportMore"><a href="#" onclick="showMore( 'CARS4-13799' )">More</a>
# </div>
# </div>
# <div id="CARS4-13799-more" style="display:none;">
# <div class="reportBodyText">
# <!-- JSF quirk: without both of these being wrapped in something like a span, there is no space between them -->
# <span class="delay-description"></span>
# <span>Between US 169 (Le Sueur) and MN 19; North 5th Street (Henderson). Look out for flooding. The road is closed. <br/><br/><i>Web Comment:</i> Highway 93 under water. Closed from Highway 19 in Henderson to Highway 169 in both directions.</span>
# </div>
# <!-- Vox events include their own 'Posted by' HTML, so we shouldn't show 'Last updated' text in that case --><div class="reportBodyText">Last updated on March 21</div>
# <div class="reportMore"><a href="#" onclick="showLess( 'CARS4-13799' )">Less</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div onmouseout="removeHighlight( 'CARS4-14204' );" onmouseover="highlight( 'CARS4-14204' );"><table class="reportTitleCritical" style="width:100%">
# <tbody>
# <tr>
# <td class="verticalAlignMiddle"></td>
# <td class="verticalAlignMiddle fullWidth">
# <div><a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A178&amp;view=state&amp;text=m&amp;textOnly=true">MN 95: Road closed.</a>
# </div></td>
# </tr>
# </tbody>
# </table>
# <div class="reportBody">
# <div id="list-entry-CARS4-14204">
# <div id="CARS4-14204-less" style="display:block;">
# <div class="reportBodyText">
# <!-- JSF quirk: without both of these being wrapped in something like a span, there is no space between them -->
# <span class="delay-description"></span>
# <span>At Fern Street North (Cambridge). The road is closed. There is a broken water main.</span>
# </div>
# <div class="reportMore"><a href="#" onclick="showMore( 'CARS4-14204' )">More</a>
# </div>
# </div>
# <div id="CARS4-14204-more" style="display:none;">
# <div class="reportBodyText">
# <!-- JSF quirk: without both of these being wrapped in something like a span, there is no space between them -->
# <span class="delay-description"></span>
# <span>At Fern Street North (Cambridge). The road is closed. There is a broken water main.</span>
# </div>
# <!-- Vox events include their own 'Posted by' HTML, so we shouldn't show 'Last updated' text in that case --><div class="reportBodyText">Last updated today at 11:30am CDT</div>
# <div class="reportMore"><a href="#" onclick="showLess( 'CARS4-14204' )">Less</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div onmouseout="removeHighlight( 'CARS4-14125' );" onmouseover="highlight( 'CARS4-14125' );"><table class="reportTitleCritical" style="width:100%">
# <tbody>
# <tr>
# <td class="verticalAlignMiddle"></td>
# <td class="verticalAlignMiddle fullWidth">
# <div><a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A201&amp;view=state&amp;text=m&amp;textOnly=true">US 75 in both directions: Flooding.</a>
# </div></td>
# </tr>
# </tbody>
# </table>
# <div class="reportBody">
# <div id="list-entry-CARS4-14125">
# <div id="CARS4-14125-less" style="display:block;">
# <div class="reportBodyText">
# <!-- JSF quirk: without both of these being wrapped in something like a span, there is no space between them -->
# <span class="delay-description"></span>
# <span>Between 220th Avenue and 230th Avenue (Halstad). Look out for flooding. The road is closed. A detour is in operation.</span>
# </div>
# <div class="reportMore"><a href="#" onclick="showMore( 'CARS4-14125' )">More</a>
# </div>
# </div>
# <div id="CARS4-14125-more" style="display:none;">
# <div class="reportBodyText">
# <!-- JSF quirk: without both of these being wrapped in something like a span, there is no space between them -->
# <span class="delay-description"></span>
# <span>Between 220th Avenue and 230th Avenue (Halstad). Look out for flooding. The road is closed. A detour is in operation. <br/><br/><i>Web Comment:</i> No OSOW restrictions.</span>
# </div>
# <!-- Vox events include their own 'Posted by' HTML, so we shouldn't show 'Last updated' text in that case --><div class="reportBodyText">Last updated on April 9</div>
# <div class="reportMore"><a href="#" onclick="showLess( 'CARS4-14125' )">Less</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div onmouseout="removeHighlight( 'CARS4-14163' );" onmouseover="highlight( 'CARS4-14163' );"><table class="reportTitleCritical" style="width:100%">
# <tbody>
# <tr>
# <td class="verticalAlignMiddle"></td>
# <td class="verticalAlignMiddle fullWidth">
# <div><a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A10&amp;view=state&amp;text=m&amp;textOnly=true">MN 1: Flooding.</a>
# </div></td>
# </tr>
# </tbody>
# </table>
# <div class="reportBody">
# <div id="list-entry-CARS4-14163">
# <div id="CARS4-14163-less" style="display:block;">
# <div class="reportBodyText">
# <!-- JSF quirk: without both of these being wrapped in something like a span, there is no space between them -->
# <span class="delay-description"></span>
# <span>Between North Dakota State Line (Oslo) and 470th Avenue Northwest (near Alvarado). Look out for flooding. The road is closed.</span>
# </div>
# <div class="reportMore"><a href="#" onclick="showMore( 'CARS4-14163' )">More</a>
# </div>
# </div>
# <div id="CARS4-14163-more" style="display:none;">
# <div class="reportBodyText">
# <!-- JSF quirk: without both of these being wrapped in something like a span, there is no space between them -->
# <span class="delay-description"></span>
# <span>Between North Dakota State Line (Oslo) and 470th Avenue Northwest (near Alvarado). Look out for flooding. The road is closed.</span>
# </div>
# <!-- Vox events include their own 'Posted by' HTML, so we shouldn't show 'Last updated' text in that case --><div class="reportBodyText">Last updated on April 12</div>
# <div class="reportMore"><a href="#" onclick="showLess( 'CARS4-14163' )">Less</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div onmouseout="removeHighlight( 'CARS4-13879' );" onmouseover="highlight( 'CARS4-13879' );"><table class="reportTitleCritical" style="width:100%">
# <tbody>
# <tr>
# <td class="verticalAlignMiddle"></td>
# <td class="verticalAlignMiddle fullWidth">
# <div><a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A130&amp;view=state&amp;text=m&amp;textOnly=true">MN 41: Flooding.</a>
# </div></td>
# </tr>
# </tbody>
# </table>
# <div class="reportBody">
# <div id="list-entry-CARS4-13879">
# <div id="CARS4-13879-less" style="display:block;">
# <div class="reportBodyText">
# <!-- JSF quirk: without both of these being wrapped in something like a span, there is no space between them -->
# <span class="delay-description"></span>
# <span>Between US 169; Chestnut Boulevard (near Carver) and East 1st Street (near Chaska). Look out for flooding. The road is closed. Until today at about 7:00PM CDT.</span>
# </div>
# <div class="reportMore"><a href="#" onclick="showMore( 'CARS4-13879' )">More</a>
# </div>
# </div>
# <div id="CARS4-13879-more" style="display:none;">
# <div class="reportBodyText">
# <!-- JSF quirk: without both of these being wrapped in something like a span, there is no space between them -->
# <span class="delay-description"></span>
# <span>Between US 169; Chestnut Boulevard (near Carver) and East 1st Street (near Chaska). Look out for flooding. The road is closed. Until today at about 7:00PM CDT. <br/><br/><i>Web Comment:</i> TH. 41 is closed between Chaska Blvd and TH. 169. due to flooding.</span>
# </div>
# <!-- Vox events include their own 'Posted by' HTML, so we shouldn't show 'Last updated' text in that case --><div class="reportBodyText">Last updated today at 3:32pm CDT</div>
# <div class="reportMore"><a href="#" onclick="showLess( 'CARS4-13879' )">Less</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div onmouseout="removeHighlight( 'CARS4-14117' );" onmouseover="highlight( 'CARS4-14117' );"><table class="reportTitleCritical" style="width:100%">
# <tbody>
# <tr>
# <td class="verticalAlignMiddle"></td>
# <td class="verticalAlignMiddle fullWidth">
# <div><a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A113&amp;view=state&amp;text=m&amp;textOnly=true">MN 317: Flooding.</a>
# </div></td>
# </tr>
# </tbody>
# </table>
# <div class="reportBody">
# <div id="list-entry-CARS4-14117">
# <div id="CARS4-14117-less" style="display:block;">
# <div class="reportBodyText">
# <!-- JSF quirk: without both of these being wrapped in something like a span, there is no space between them -->
# <span class="delay-description"></span>
# <span>Between North Dakota State Line and MN 220. Look out for flooding. The road is closed.</span>
# </div>
# <div class="reportMore"><a href="#" onclick="showMore( 'CARS4-14117' )">More</a>
# </div>
# </div>
# <div id="CARS4-14117-more" style="display:none;">
# <div class="reportBodyText">
# <!-- JSF quirk: without both of these being wrapped in something like a span, there is no space between them -->
# <span class="delay-description"></span>
# <span>Between North Dakota State Line and MN 220. Look out for flooding. The road is closed.</span>
# </div>
# <!-- Vox events include their own 'Posted by' HTML, so we shouldn't show 'Last updated' text in that case --><div class="reportBodyText">Last updated on April 12</div>
# <div class="reportMore"><a href="#" onclick="showLess( 'CARS4-14117' )">Less</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div onmouseout="removeHighlight( 'CARS4-14116' );" onmouseover="highlight( 'CARS4-14116' );"><table class="reportTitleCritical" style="width:100%">
# <tbody>
# <tr>
# <td class="verticalAlignMiddle"></td>
# <td class="verticalAlignMiddle fullWidth">
# <div><a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A53&amp;view=state&amp;text=m&amp;textOnly=true">MN 220: Flooding.</a>
# </div></td>
# </tr>
# </tbody>
# </table>
# <div class="reportBody">
# <div id="list-entry-CARS4-14116">
# <div id="CARS4-14116-less" style="display:block;">
# <div class="reportBodyText">
# <!-- JSF quirk: without both of these being wrapped in something like a span, there is no space between them -->
# <span class="delay-description"></span>
# <span>Between MN 1; 490th Avenue Northwest and 390th Street Northwest (13 miles north of the Oslo area). Look out for flooding. The road is closed.</span>
# </div>
# <div class="reportMore"><a href="#" onclick="showMore( 'CARS4-14116' )">More</a>
# </div>
# </div>
# <div id="CARS4-14116-more" style="display:none;">
# <div class="reportBodyText">
# <!-- JSF quirk: without both of these being wrapped in something like a span, there is no space between them -->
# <span class="delay-description"></span>
# <span>Between MN 1; 490th Avenue Northwest and 390th Street Northwest (13 miles north of the Oslo area). Look out for flooding. The road is closed. <br/><br/><i>Web Comment:</i> This is between MN 1 and Marshall County Road #5</span>
# </div>
# <!-- Vox events include their own 'Posted by' HTML, so we shouldn't show 'Last updated' text in that case --><div class="reportBodyText">Last updated on April 12</div>
# <div class="reportMore"><a href="#" onclick="showLess( 'CARS4-14116' )">Less</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div onmouseout="removeHighlight( 'CARS4-14159' );" onmouseover="highlight( 'CARS4-14159' );"><table class="reportTitleCritical" style="width:100%">
# <tbody>
# <tr>
# <td class="verticalAlignMiddle"></td>
# <td class="verticalAlignMiddle fullWidth">
# <div><a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A201&amp;view=state&amp;text=m&amp;textOnly=true">US 75 in both directions: Flooding.</a>
# </div></td>
# </tr>
# </tbody>
# </table>
# <div class="reportBody">
# <div id="list-entry-CARS4-14159">
# <div id="CARS4-14159-less" style="display:block;">
# <div class="reportBodyText">
# <!-- JSF quirk: without both of these being wrapped in something like a span, there is no space between them -->
# <span class="delay-description"></span>
# <span>At Northeast 3rd Street (Climax). Look out for flooding. The road is closed.</span>
# </div>
# <div class="reportMore"><a href="#" onclick="showMore( 'CARS4-14159' )">More</a>
# </div>
# </div>
# <div id="CARS4-14159-more" style="display:none;">
# <div class="reportBodyText">
# <!-- JSF quirk: without both of these being wrapped in something like a span, there is no space between them -->
# <span class="delay-description"></span>
# <span>At Northeast 3rd Street (Climax). Look out for flooding. The road is closed. <br/><br/><i>Web Comment:</i> Closed until further notice</span>
# </div>
# <!-- Vox events include their own 'Posted by' HTML, so we shouldn't show 'Last updated' text in that case --><div class="reportBodyText">Last updated on April 11</div>
# <div class="reportMore"><a href="#" onclick="showLess( 'CARS4-14159' )">Less</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div onmouseout="removeHighlight( 'CARS4-14155' );" onmouseover="highlight( 'CARS4-14155' );"><table class="reportTitleCritical" style="width:100%">
# <tbody>
# <tr>
# <td class="verticalAlignMiddle"></td>
# <td class="verticalAlignMiddle fullWidth">
# <div><a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A201&amp;view=state&amp;text=m&amp;textOnly=true">US 75 in both directions: Flooding.</a>
# </div></td>
# </tr>
# </tbody>
# </table>
# <div class="reportBody">
# <div id="list-entry-CARS4-14155">
# <div id="CARS4-14155-less" style="display:block;">
# <div class="reportBodyText">
# <!-- JSF quirk: without both of these being wrapped in something like a span, there is no space between them -->
# <span class="delay-description"></span>
# <span>Between MN 200; 3rd Street East and 250th Avenue (Halstad). Look out for flooding. The road is closed.</span>
# </div>
# <div class="reportMore"><a href="#" onclick="showMore( 'CARS4-14155' )">More</a>
# </div>
# </div>
# <div id="CARS4-14155-more" style="display:none;">
# <div class="reportBodyText">
# <!-- JSF quirk: without both of these being wrapped in something like a span, there is no space between them -->
# <span class="delay-description"></span>
# <span>Between MN 200; 3rd Street East and 250th Avenue (Halstad). Look out for flooding. The road is closed.</span>
# </div>
# <!-- Vox events include their own 'Posted by' HTML, so we shouldn't show 'Last updated' text in that case --><div class="reportBodyText">Last updated on April 11</div>
# <div class="reportMore"><a href="#" onclick="showLess( 'CARS4-14155' )">Less</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div onmouseout="removeHighlight( 'CARS4-14077' );" onmouseover="highlight( 'CARS4-14077' );"><table class="reportTitleCritical" style="width:100%">
# <tbody>
# <tr>
# <td class="verticalAlignMiddle"></td>
# <td class="verticalAlignMiddle fullWidth">
# <div><a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A154&amp;view=state&amp;text=m&amp;textOnly=true">MN 67: Road closed to traffic.</a>
# </div></td>
# </tr>
# </tbody>
# </table>
# <div class="reportBody">
# <div id="list-entry-CARS4-14077">
# <div id="CARS4-14077-less" style="display:block;">
# <div class="reportBodyText">
# <!-- JSF quirk: without both of these being wrapped in something like a span, there is no space between them -->
# <span class="delay-description"></span>
# <span>Between County Road B1 and 600th Street (1 mile east of the Granite Falls area). The road is closed to traffic. The road surface has collapsed.</span>
# </div>
# <div class="reportMore"><a href="#" onclick="showMore( 'CARS4-14077' )">More</a>
# </div>
# </div>
# <div id="CARS4-14077-more" style="display:none;">
# <div class="reportBodyText">
# <!-- JSF quirk: without both of these being wrapped in something like a span, there is no space between them -->
# <span class="delay-description"></span>
# <span>Between County Road B1 and 600th Street (1 mile east of the Granite Falls area). The road is closed to traffic. The road surface has collapsed.</span>
# </div>
# <!-- Vox events include their own 'Posted by' HTML, so we shouldn't show 'Last updated' text in that case --><div class="reportBodyText">Last updated on April 5</div>
# <div class="reportMore"><a href="#" onclick="showLess( 'CARS4-14077' )">Less</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div onmouseout="removeHighlight( 'CARS4-13699' );" onmouseover="highlight( 'CARS4-13699' );"><table class="reportTitleCritical" style="width:100%">
# <tbody>
# <tr>
# <td class="verticalAlignMiddle"></td>
# <td class="verticalAlignMiddle fullWidth">
# <div><a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A160&amp;view=state&amp;text=m&amp;textOnly=true">MN 74 in both directions: Flooding.</a>
# </div></td>
# </tr>
# </tbody>
# </table>
# <div class="reportBody">
# <div id="list-entry-CARS4-13699">
# <div id="CARS4-13699-less" style="display:block;">
# <div class="reportBodyText">
# <!-- JSF quirk: without both of these being wrapped in something like a span, there is no space between them -->
# <span class="delay-description"></span>
# <span>Between County Road 30 (1 mile north of the Elba area) and US 61 (near Minneiska). Look out for flooding. The road is closed. Use a detour where possible.</span>
# </div>
# <div class="reportMore"><a href="#" onclick="showMore( 'CARS4-13699' )">More</a>
# </div>
# </div>
# <div id="CARS4-13699-more" style="display:none;">
# <div class="reportBodyText">
# <!-- JSF quirk: without both of these being wrapped in something like a span, there is no space between them -->
# <span class="delay-description"></span>
# <span>Between County Road 30 (1 mile north of the Elba area) and US 61 (near Minneiska). Look out for flooding. The road is closed. Use a detour where possible. <br/><br/><i>Web Comment:</i> Road closed until further notice</span>
# </div>
# <!-- Vox events include their own 'Posted by' HTML, so we shouldn't show 'Last updated' text in that case --><div class="reportBodyText">Last updated on March 26</div>
# <div class="reportMore"><a href="#" onclick="showLess( 'CARS4-13699' )">Less</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div onmouseout="removeHighlight( 'CARS4-13938' );" onmouseover="highlight( 'CARS4-13938' );"><table class="reportTitleCritical" style="width:100%">
# <tbody>
# <tr>
# <td class="verticalAlignMiddle"></td>
# <td class="verticalAlignMiddle fullWidth">
# <div><a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A147&amp;view=state&amp;text=m&amp;textOnly=true">MN 60: Flooding.</a>
# </div></td>
# </tr>
# </tbody>
# </table>
# <div class="reportBody">
# <div id="list-entry-CARS4-13938">
# <div id="CARS4-13938-less" style="display:block;">
# <div class="reportBodyText">
# <!-- JSF quirk: without both of these being wrapped in something like a span, there is no space between them -->
# <span class="delay-description"></span>
# <span>Between US 61 and Hiawatha Drive West (Wabasha). Look out for flooding. The road is closed.</span>
# </div>
# <div class="reportMore"><a href="#" onclick="showMore( 'CARS4-13938' )">More</a>
# </div>
# </div>
# <div id="CARS4-13938-more" style="display:none;">
# <div class="reportBodyText">
# <!-- JSF quirk: without both of these being wrapped in something like a span, there is no space between them -->
# <span class="delay-description"></span>
# <span>Between US 61 and Hiawatha Drive West (Wabasha). Look out for flooding. The road is closed.</span>
# </div>
# <!-- Vox events include their own 'Posted by' HTML, so we shouldn't show 'Last updated' text in that case --><div class="reportBodyText">Last updated on March 27</div>
# <div class="reportMore"><a href="#" onclick="showLess( 'CARS4-13938' )">Less</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div onmouseout="removeHighlight( 'CARS4-13979' );" onmouseover="highlight( 'CARS4-13979' );"><table class="reportTitleCritical" style="width:100%">
# <tbody>
# <tr>
# <td class="verticalAlignMiddle"></td>
# <td class="verticalAlignMiddle fullWidth">
# <div><a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A154&amp;view=state&amp;text=m&amp;textOnly=true">MN 67: Flooding.</a>
# </div></td>
# </tr>
# </tbody>
# </table>
# <div class="reportBody">
# <div id="list-entry-CARS4-13979">
# <div id="CARS4-13979-less" style="display:block;">
# <div class="reportBodyText">
# <!-- JSF quirk: without both of these being wrapped in something like a span, there is no space between them -->
# <span class="delay-description"></span>
# <span>Between 558th Street and 255th Avenue (near Granite Falls). Look out for flooding. The road is closed.</span>
# </div>
# <div class="reportMore"><a href="#" onclick="showMore( 'CARS4-13979' )">More</a>
# </div>
# </div>
# <div id="CARS4-13979-more" style="display:none;">
# <div class="reportBodyText">
# <!-- JSF quirk: without both of these being wrapped in something like a span, there is no space between them -->
# <span class="delay-description"></span>
# <span>Between 558th Street and 255th Avenue (near Granite Falls). Look out for flooding. The road is closed. <br/><br/><i>Web Comment:</i> A portion of the roadway just west of the Yellow Medicine River Bridge on Highway 67 south of Granite Falls (near the state park entrance) has shifted, causing a significant drop in the driving lane and creating a hazardous condition. </span>
# </div>
# <!-- Vox events include their own 'Posted by' HTML, so we shouldn't show 'Last updated' text in that case --><div class="reportBodyText">Last updated on April 9</div>
# <div class="reportMore"><a href="#" onclick="showLess( 'CARS4-13979' )">Less</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </body>
# </html>

# %%
soup.find('div', {'class': "reportBodyText"}).text.strip()
# Out:
# 'Between MN 93; North 5th Street and US 169 (near Henderson). Look out for flooding. The road is closed.'

# %%
soup.find('table', {'class': "reportTitleCritical"}).text.strip()
# Out:
# 'MN 19: Flooding.'

# %%
soup.find_all('table', {'class': "reportTitleCritical"})
# Out:
# [<table class="reportTitleCritical" style="width:100%">
#  <tbody>
#  <tr>
#  <td class="verticalAlignMiddle"></td>
#  <td class="verticalAlignMiddle fullWidth">
#  <div><a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A43&amp;view=state&amp;text=m&amp;textOnly=true">MN 19: Flooding.</a>
#  </div></td>
#  </tr>
#  </tbody>
#  </table>, <table class="reportTitleCritical" style="width:100%">
#  <tbody>
#  <tr>
#  <td class="verticalAlignMiddle"></td>
#  <td class="verticalAlignMiddle fullWidth">
#  <div><a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A177&amp;view=state&amp;text=m&amp;textOnly=true">MN 93: Flooding.</a>
#  </div></td>
#  </tr>
#  </tbody>
#  </table>, <table class="reportTitleCritical" style="width:100%">
#  <tbody>
#  <tr>
#  <td class="verticalAlignMiddle"></td>
#  <td class="verticalAlignMiddle fullWidth">
#  <div><a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A178&amp;view=state&amp;text=m&amp;textOnly=true">MN 95: Road closed.</a>
#  </div></td>
#  </tr>
#  </tbody>
#  </table>, <table class="reportTitleCritical" style="width:100%">
#  <tbody>
#  <tr>
#  <td class="verticalAlignMiddle"></td>
#  <td class="verticalAlignMiddle fullWidth">
#  <div><a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A201&amp;view=state&amp;text=m&amp;textOnly=true">US 75 in both directions: Flooding.</a>
#  </div></td>
#  </tr>
#  </tbody>
#  </table>, <table class="reportTitleCritical" style="width:100%">
#  <tbody>
#  <tr>
#  <td class="verticalAlignMiddle"></td>
#  <td class="verticalAlignMiddle fullWidth">
#  <div><a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A10&amp;view=state&amp;text=m&amp;textOnly=true">MN 1: Flooding.</a>
#  </div></td>
#  </tr>
#  </tbody>
#  </table>, <table class="reportTitleCritical" style="width:100%">
#  <tbody>
#  <tr>
#  <td class="verticalAlignMiddle"></td>
#  <td class="verticalAlignMiddle fullWidth">
#  <div><a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A130&amp;view=state&amp;text=m&amp;textOnly=true">MN 41: Flooding.</a>
#  </div></td>
#  </tr>
#  </tbody>
#  </table>, <table class="reportTitleCritical" style="width:100%">
#  <tbody>
#  <tr>
#  <td class="verticalAlignMiddle"></td>
#  <td class="verticalAlignMiddle fullWidth">
#  <div><a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A113&amp;view=state&amp;text=m&amp;textOnly=true">MN 317: Flooding.</a>
#  </div></td>
#  </tr>
#  </tbody>
#  </table>, <table class="reportTitleCritical" style="width:100%">
#  <tbody>
#  <tr>
#  <td class="verticalAlignMiddle"></td>
#  <td class="verticalAlignMiddle fullWidth">
#  <div><a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A53&amp;view=state&amp;text=m&amp;textOnly=true">MN 220: Flooding.</a>
#  </div></td>
#  </tr>
#  </tbody>
#  </table>, <table class="reportTitleCritical" style="width:100%">
#  <tbody>
#  <tr>
#  <td class="verticalAlignMiddle"></td>
#  <td class="verticalAlignMiddle fullWidth">
#  <div><a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A201&amp;view=state&amp;text=m&amp;textOnly=true">US 75 in both directions: Flooding.</a>
#  </div></td>
#  </tr>
#  </tbody>
#  </table>, <table class="reportTitleCritical" style="width:100%">
#  <tbody>
#  <tr>
#  <td class="verticalAlignMiddle"></td>
#  <td class="verticalAlignMiddle fullWidth">
#  <div><a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A201&amp;view=state&amp;text=m&amp;textOnly=true">US 75 in both directions: Flooding.</a>
#  </div></td>
#  </tr>
#  </tbody>
#  </table>, <table class="reportTitleCritical" style="width:100%">
#  <tbody>
#  <tr>
#  <td class="verticalAlignMiddle"></td>
#  <td class="verticalAlignMiddle fullWidth">
#  <div><a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A154&amp;view=state&amp;text=m&amp;textOnly=true">MN 67: Road closed to traffic.</a>
#  </div></td>
#  </tr>
#  </tbody>
#  </table>, <table class="reportTitleCritical" style="width:100%">
#  <tbody>
#  <tr>
#  <td class="verticalAlignMiddle"></td>
#  <td class="verticalAlignMiddle fullWidth">
#  <div><a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A160&amp;view=state&amp;text=m&amp;textOnly=true">MN 74 in both directions: Flooding.</a>
#  </div></td>
#  </tr>
#  </tbody>
#  </table>, <table class="reportTitleCritical" style="width:100%">
#  <tbody>
#  <tr>
#  <td class="verticalAlignMiddle"></td>
#  <td class="verticalAlignMiddle fullWidth">
#  <div><a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A147&amp;view=state&amp;text=m&amp;textOnly=true">MN 60: Flooding.</a>
#  </div></td>
#  </tr>
#  </tbody>
#  </table>, <table class="reportTitleCritical" style="width:100%">
#  <tbody>
#  <tr>
#  <td class="verticalAlignMiddle"></td>
#  <td class="verticalAlignMiddle fullWidth">
#  <div><a href="/mnlb/roadreports/critical_reports.jsf;jsessionid=-DF2z0iaJ6SoxlkU-gTPhGLBzoVfm4Argi3-_hDj.ip-10-4-73-183?route=27%3A154&amp;view=state&amp;text=m&amp;textOnly=true">MN 67: Flooding.</a>
#  </div></td>
#  </tr>
#  </tbody>
#  </table>]

# %%
headers = []
for li in soup.find_all('table', {'class': "reportTitleCritical"}):
    print(li.text.strip())
    headers.append(li.text.strip())
# Out:
# MN 19: Flooding.
# MN 93: Flooding.
# MN 95: Road closed.
# US 75 in both directions: Flooding.
# MN 1: Flooding.
# MN 41: Flooding.
# MN 317: Flooding.
# MN 220: Flooding.
# US 75 in both directions: Flooding.
# US 75 in both directions: Flooding.
# MN 67: Road closed to traffic.
# MN 74 in both directions: Flooding.
# MN 60: Flooding.
# MN 67: Flooding.

# %%
text = []
for li in soup.find_all('div', {'class': "reportBodyText"}):
    print(li.text.strip())
    text.append(li.text.strip())
# Out:
# Between MN 93; North 5th Street and US 169 (near Henderson). Look out for flooding. The road is closed.
# Between MN 93; North 5th Street and US 169 (near Henderson). Look out for flooding. The road is closed. Web Comment: Detour where possible
# Last updated on March 19
# Between US 169 (Le Sueur) and MN 19; North 5th Street (Henderson). Look out for flooding. The road is closed.
# Between US 169 (Le Sueur) and MN 19; North 5th Street (Henderson). Look out for flooding. The road is closed. Web Comment: Highway 93 under water. Closed from Highway 19 in Henderson to Highway 169 in both directions.
# Last updated on March 21
# At Fern Street North (Cambridge). The road is closed. There is a broken water main.
# At Fern Street North (Cambridge). The road is closed. There is a broken water main.
# Last updated today at 11:30am CDT
# Between 220th Avenue and 230th Avenue (Halstad). Look out for flooding. The road is closed. A detour is in operation.
# Between 220th Avenue and 230th Avenue (Halstad). Look out for flooding. The road is closed. A detour is in operation. Web Comment: No OSOW restrictions.
# Last updated on April 9
# Between North Dakota State Line (Oslo) and 470th Avenue Northwest (near Alvarado). Look out for flooding. The road is closed.
# Between North Dakota State Line (Oslo) and 470th Avenue Northwest (near Alvarado). Look out for flooding. The road is closed.
# Last updated on April 12
# Between US 169; Chestnut Boulevard (near Carver) and East 1st Street (near Chaska). Look out for flooding. The road is closed. Until today at about 7:00PM CDT.
# Between US 169; Chestnut Boulevard (near Carver) and East 1st Street (near Chaska). Look out for flooding. The road is closed. Until today at about 7:00PM CDT. Web Comment: TH. 41 is closed between Chaska Blvd and TH. 169. due to flooding.
# Last updated today at 3:32pm CDT
# Between North Dakota State Line and MN 220. Look out for flooding. The road is closed.
# Between North Dakota State Line and MN 220. Look out for flooding. The road is closed.
# Last updated on April 12
# Between MN 1; 490th Avenue Northwest and 390th Street Northwest (13 miles north of the Oslo area). Look out for flooding. The road is closed.
# Between MN 1; 490th Avenue Northwest and 390th Street Northwest (13 miles north of the Oslo area). Look out for flooding. The road is closed. Web Comment: This is between MN 1 and Marshall County Road #5
# Last updated on April 12
# At Northeast 3rd Street (Climax). Look out for flooding. The road is closed.
# At Northeast 3rd Street (Climax). Look out for flooding. The road is closed. Web Comment: Closed until further notice
# Last updated on April 11
# Between MN 200; 3rd Street East and 250th Avenue (Halstad). Look out for flooding. The road is closed.
# Between MN 200; 3rd Street East and 250th Avenue (Halstad). Look out for flooding. The road is closed.
# Last updated on April 11
# Between County Road B1 and 600th Street (1 mile east of the Granite Falls area). The road is closed to traffic. The road surface has collapsed.
# Between County Road B1 and 600th Street (1 mile east of the Granite Falls area). The road is closed to traffic. The road surface has collapsed.
# Last updated on April 5
# Between County Road 30 (1 mile north of the Elba area) and US 61 (near Minneiska). Look out for flooding. The road is closed. Use a detour where possible.
# Between County Road 30 (1 mile north of the Elba area) and US 61 (near Minneiska). Look out for flooding. The road is closed. Use a detour where possible. Web Comment: Road closed until further notice
# Last updated on March 26
# Between US 61 and Hiawatha Drive West (Wabasha). Look out for flooding. The road is closed.
# Between US 61 and Hiawatha Drive West (Wabasha). Look out for flooding. The road is closed.
# Last updated on March 27
# Between 558th Street and 255th Avenue (near Granite Falls). Look out for flooding. The road is closed.
# Between 558th Street and 255th Avenue (near Granite Falls). Look out for flooding. The road is closed. Web Comment: A portion of the roadway just west of the Yellow Medicine River Bridge on Highway 67 south of Granite Falls (near the state park entrance) has shifted, causing a significant drop in the driving lane and creating a hazardous condition.
# Last updated on April 9

# %%
#the text of each element gets pulled in three times, need to only use the full text, which is the third
text_full = text[0::3]

# %%
d = {'Header':headers,'Text':text_full}

# %%
df_mn_511 = pd.DataFrame(d)

# %% [markdown]
# # Spacy Location Detection  <a class="anchor" id="sixth-bullet"></a>

# %% [markdown]
# Below is a function that is defined to apply spaCy location detection to text columns.  spaCy is a package (imported above) that uses a neural network to extract named entities.  This can be used to identify people, places, locations, companies, among others.  In this case we will be looking to extract location names.  These named locations will be used to both in the data preperation step of our modeling as well as in the final mapping stage.

# %%
# apply spacy function
def apply_spacy(input_column):
    locations = []
    for i in input_column:
        doc = nlp(i)
        locations.append([(X.text, X.label_) for X in doc.ents])
    locations_and_dates = []
    for i in locations:
# the GPE list contains more categories than we are interested in.  we really are only looking for locations and dates
#so we will filter the list here to those two categories before we append it to our dataframe
        #print(i)
        locs = []
        for j in i:
            if j[1] in ('DATE', 'GPE'):
                locs.append(j)
        locations_and_dates.append(locs)
    print(locations_and_dates)
    return locations_and_dates

# %% [markdown]
# ## Apply Spacy to Weather API

# %%
weather_df['location'] = apply_spacy(weather_df['description'] )
# Out:
# [[], [('Savageton', 'GPE')], [('Indiana', 'GPE'), ('Indiana', 'GPE'), ('Thursday', 'DATE'), ('Tuesday', 'DATE'), ('tomorrow', 'DATE'), ('the week', 'DATE'), ('Rivervale', 'GPE'), ('Sunday', 'DATE'), ('Monday April 29', 'DATE'), ('Saturday', 'DATE'), ('Sunday', 'DATE'), ('Wednesday', 'DATE'), ('Sunday April 28', 'DATE')], [('Indiana', 'GPE'), ('Indiana', 'GPE'), ('Thursday', 'DATE'), ('Tuesday', 'DATE'), ('tomorrow', 'DATE'), ('the week', 'DATE'), ('Seymour', 'GPE'), ('Thursday', 'DATE'), ('Saturday', 'DATE'), ('Sunday', 'DATE'), ('June 2010', 'DATE'), ('a few days earlier', 'DATE')], [('Indiana', 'GPE'), ('Indiana', 'GPE'), ('Thursday', 'DATE'), ('Tuesday', 'DATE'), ('tomorrow', 'DATE'), ('the week', 'DATE'), ('Columbus', 'GPE'), ('Saturday', 'DATE'), ('Sunday', 'DATE'), ('Monday', 'DATE'), ('April 6, 2011', 'DATE')], [('Indiana', 'GPE'), ('Indiana', 'GPE'), ('Thursday', 'DATE'), ('Tuesday', 'DATE'), ('tomorrow', 'DATE'), ('the week', 'DATE'), ('Ridgeville', 'GPE'), ('Saturday', 'DATE'), ('Randolph County', 'GPE'), ('Ridgeville', 'GPE')], [('Indiana', 'GPE'), ('Indiana', 'GPE'), ('Thursday', 'DATE'), ('Tuesday', 'DATE'), ('tomorrow', 'DATE'), ('the week', 'DATE'), ('Noblesville', 'GPE'), ('Saturday', 'DATE'), ('Sunday', 'DATE'), ('Sunday', 'DATE'), ('Sunday', 'DATE'), ('Noblesville', 'GPE')], [('Indiana', 'GPE'), ('Indiana', 'GPE'), ('Thursday', 'DATE'), ('Tuesday', 'DATE'), ('tomorrow', 'DATE'), ('the week', 'DATE'), ('Sunday', 'DATE'), ('Saturday', 'DATE')], [('Indiana', 'GPE'), ('Indiana', 'GPE'), ('Thursday', 'DATE'), ('Tuesday', 'DATE'), ('tomorrow', 'DATE'), ('the week', 'DATE'), ('Saturday', 'DATE'), ('Bartholomew County', 'GPE'), ('April 6, 2011', 'DATE'), ('CR', 'GPE'), ('CR', 'GPE'), ('1000S', 'DATE'), ('CR', 'GPE')], [('Indiana', 'GPE'), ('Indiana', 'GPE'), ('Thursday', 'DATE'), ('Tuesday', 'DATE'), ('tomorrow', 'DATE'), ('the week', 'DATE'), ('Saturday', 'DATE'), ('Thursday', 'DATE'), ('Gosport', 'GPE')], [('Indiana', 'GPE'), ('Indiana', 'GPE'), ('Thursday', 'DATE'), ('Tuesday', 'DATE'), ('tomorrow', 'DATE'), ('the week', 'DATE'), ('Saturday', 'DATE')], [('Indiana', 'GPE'), ('Indiana', 'GPE'), ('Thursday', 'DATE'), ('Tuesday', 'DATE'), ('tomorrow', 'DATE'), ('the week', 'DATE'), ('Elliston', 'GPE'), ('Saturday April 27', 'DATE'), ('Saturday', 'DATE'), ('Sunday', 'DATE'), ('Friday', 'DATE')], [('Indiana', 'GPE'), ('Indiana', 'GPE'), ('Thursday', 'DATE'), ('Tuesday', 'DATE'), ('tomorrow', 'DATE'), ('the week', 'DATE'), ('Sunday April 28', 'DATE'), ('Saturday', 'DATE'), ('Monday', 'DATE'), ('Saturday April 27', 'DATE'), ('June 2010', 'DATE'), ('March 2011', 'DATE'), ('Plainville', 'GPE')], [('Indiana', 'GPE'), ('Indiana', 'GPE'), ('Thursday', 'DATE'), ('Tuesday', 'DATE'), ('tomorrow', 'DATE'), ('the week', 'DATE'), ('Sunday', 'DATE'), ('Monday', 'DATE'), ('Ravenswood', 'GPE')], [('Indiana', 'GPE'), ('Indiana', 'GPE'), ('Thursday', 'DATE'), ('Tuesday', 'DATE'), ('tomorrow', 'DATE'), ('the week', 'DATE'), ('Bedford', 'GPE'), ('Monday', 'DATE'), ('Wednesday', 'DATE'), ('Sunday April 28', 'DATE')], [('Indiana', 'GPE'), ('Indiana', 'GPE'), ('Thursday', 'DATE'), ('Tuesday', 'DATE'), ('tomorrow', 'DATE'), ('the week', 'DATE'), ('Saturday', 'DATE'), ('Sunday', 'DATE'), ('Monday', 'DATE')], [('Indiana', 'GPE'), ('Indiana', 'GPE'), ('Thursday', 'DATE'), ('Tuesday', 'DATE'), ('tomorrow', 'DATE'), ('the week', 'DATE'), ('Monday April 29', 'DATE'), ('Saturday', 'DATE'), ('Monday', 'DATE'), ('Sunday April 28', 'DATE')], [('Indiana', 'GPE'), ('Indiana', 'GPE'), ('Thursday', 'DATE'), ('Tuesday', 'DATE'), ('tomorrow', 'DATE'), ('the week', 'DATE'), ('Saturday', 'DATE'), ('April 20, 2011', 'DATE')], [('Perry', 'GPE'), ('Brigham City', 'GPE'), ('Logan', 'GPE'), ('Brigham City', 'GPE'), ('Hyrum', 'GPE'), ('Perry', 'GPE'), ('Wellsville', 'GPE'), ('Willard', 'GPE'), ('Mantua', 'GPE'), ('Corinne', 'GPE'), ('South Willard', 'GPE'), ('North Logan', 'GPE'), ('Park', 'GPE'), ('Millville', 'GPE'), ('River Heights', 'GPE'), ('Honeyville', 'GPE')] ...

# %%
#weather_df.to_csv('./data/weather_api.csv')

# %% [markdown]
# ## Apply Spacy to News API

# %%
# there are  rows with null content, these should be removed
df_news_all_topics.content.isnull().sum()
# Out:
# 119

# %%
df_news_all_topics = df_news_all_topics.dropna(subset=['content'])

# %%
df_news_all_topics.content.isnull().sum()
# Out:
# 0

# %%
df_news_all_topics['locations_and_times']  = apply_spacy(df_news_all_topics['content'] )

# %%
df_news_export = df_news_all_topics[['publishedAt', 'content', 'url', 'locations_and_times']]

# %%
#df_news_export.to_csv(./data/news_api.csv)

# %% [markdown]
# ## Apply Spacy to MN 511

# %%
df_mn_511.head()
# Out:
#                                 Header  \
# 0                     MN 19: Flooding.
# 1                     MN 93: Flooding.
# 2                  MN 95: Road closed.
# 3  US 75 in both directions: Flooding.
# 4                      MN 1: Flooding.
#
#                                                 Text
# 0  Between MN 93; North 5th Street and US 169 (ne...
# 1  Between US 169 (Le Sueur) and MN 19; North 5th...
# 2  At Fern Street North (Cambridge). The road is ...
# 3  Between 220th Avenue and 230th Avenue (Halstad...
# 4  Between North Dakota State Line (Oslo) and 470...

# %%
df_mn_511['locations_and_times'] = apply_spacy(df_mn_511['Text'] )

# %%
df_mn_511
# Out:
#                                  Header  \
# 0                      MN 19: Flooding.
# 1                      MN 93: Flooding.
# 2                   MN 95: Road closed.
# 3   US 75 in both directions: Flooding.
# 4                       MN 1: Flooding.
# 5                      MN 41: Flooding.
# 6                     MN 317: Flooding.
# 7                     MN 220: Flooding.
# 8   US 75 in both directions: Flooding.
# 9   US 75 in both directions: Flooding.
# 10       MN 67: Road closed to traffic.
# 11  MN 74 in both directions: Flooding.
# 12                     MN 60: Flooding.
# 13                     MN 67: Flooding.
#
#                                                  Text  \
# 0   Between MN 93; North 5th Street and US 169 (ne...
# 1   Between US 169 (Le Sueur) and MN 19; North 5th...
# 2   At Fern Street North (Cambridge). The road is ...
# 3   Between 220th Avenue and 230th Avenue (Halstad...
# 4   Between North Dakota State Line (Oslo) and 470...
# 5   Between US 169; Chestnut Boulevard (near Carve...
# 6   Between North Dakota State Line and MN 220. Lo...
# 7   Between MN 1; 490th Avenue Northwest and 390th...
# 8   At Northeast 3rd Street (Climax). Look out for...
# 9   Between MN 200; 3rd Street East and 250th Aven...
# 10  Between County Road B1 and 600th Street (1 mil...
# 11  Between County Road 30 (1 mile north of the El...
# 12  Between US 61 and Hiawatha Drive West (Wabasha...
# 13  Between 558th Street and 255th Avenue (near Gr...
#
#                                   locations_and_times
# 0         [(North 5th Street, GPE), (Henderson, GPE)]
# 1                                         [(US, GPE)]
# 2                                                  []
# 3                                                  []
# 4   [(North Dakota, GPE), (Oslo, GPE), (Alvarado, ...
# 5   [(US, GPE), (Carver, GPE), (Chaska, GPE), (tod...
# 6                    [(North Dakota State Line, GPE)]
# 7                                       [(Oslo, GPE)]
# 8                                                  []
# 9                                                  []
# 10                                                 []
# 11         [(Elba, GPE), (US, GPE), (Minneiska, GPE)]
# 12  [(US, GPE), (61, DATE), (Hiawatha Drive West, ...
# 13                                                 []

# %%
#df_mn_511.to_csv('./data/mn_511.csv')

# %% [markdown]
# Now that we have pulled in our data, applied Spacy named entities to it, and exported all needed files to CSV.  We will begin modelling our data to filter it down to only relevant alerts.  Finally, we will map these relevant road closures.
